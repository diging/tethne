# %%
import tethne.readers as rd
filepath = "../testsuite/testin/cocitations_#62657522.txt"
wos_list = rd.wos.parse_wos(filepath)

meta_list=rd.wos.wos2meta(wos_list)

import tethne.networks as nt
for paper in meta_list:
    print paper['ayjid']

coinst = nt.papers.cocitation(meta_list, 2)

asstr=('ADRIANO D. 2001 TRACE ELEMENTS TERRE', 'RAO J 1992 RNEA TECHN B SER LAN')
print asstr[1]

import tethne.writers as wr
wr.graph.to_gexf(coinst, "../testsuite/testout/cocitation_1threshold_dec20")
# Out:
# MODIS K 2014
# TUERHONG G 2014
# except except : ADRIANO D. 2001 TRACE ELEMENTS TERRE RAO J 1992 RNEA TECHN B SER LAN
# except except : ADRIANO D. 2001 TRACE ELEMENTS TERRE FILIPPIDIS A 1992 FUEL
# except except : ADRIANO D. 2001 TRACE ELEMENTS TERRE VATALIS K. 2006 ENVIRON MANAGE
# except except : ADRIANO D. 2001 TRACE ELEMENTS TERRE XIAO HY 2011 SOIL SEDIMENT CONTAM
# except except : ADRIANO D. 2001 TRACE ELEMENTS TERRE YU HL 2007 STOCH ENV RES RISK A
# except except : RAO J 1992 RNEA TECHN B SER LAN FILIPPIDIS A 1992 FUEL
# except except : RAO J 1992 RNEA TECHN B SER LAN VATALIS K. 2006 ENVIRON MANAGE
# except except : RAO J 1992 RNEA TECHN B SER LAN XIAO HY 2011 SOIL SEDIMENT CONTAM
# except except : RAO J 1992 RNEA TECHN B SER LAN YU HL 2007 STOCH ENV RES RISK A
# except except : FILIPPIDIS A 1992 FUEL VATALIS K. 2006 ENVIRON MANAGE
# except except : FILIPPIDIS A 1992 FUEL XIAO HY 2011 SOIL SEDIMENT CONTAM
# except except : FILIPPIDIS A 1992 FUEL YU HL 2007 STOCH ENV RES RISK A
# except except : VATALIS K. 2006 ENVIRON MANAGE XIAO HY 2011 SOIL SEDIMENT CONTAM
# except except : VATALIS K. 2006 ENVIRON MANAGE YU HL 2007 STOCH ENV RES RISK A
# except except : XIAO HY 2011 SOIL SEDIMENT CONTAM YU HL 2007 STOCH ENV RES RISK A
# except except : ANGIULLI F 2005 IEEE T KNOWL DATA EN CHAKRABORTI S 2001 J QUAL TECHNOL
# except except : ANGIULLI F 2005 IEEE T KNOWL DATA EN DAS N 2009 QUAL TECHNOL QUANT M
# except except : ANGIULLI F 2005 IEEE T KNOWL DATA EN EFRON B. 1993 INTRO BOOTSTRAP
# except except : ANGIULLI F 2005 IEEE T KNOWL DATA EN FRANK A. 2010 UCI MACHINE LEARNING
# except except : ANGIULLI F 2005 IEEE T KNOWL DATA EN RAO J 1992 RNEA TECHN B SER LAN
# except except : ANGIULLI F 2005 IEEE T KNOWL DATA EN FILIPPIDIS A 1992 FUEL
# except except : ANGIULLI F 2005 IEEE T KNOWL DATA EN ZOU CK 2011 TECHNOMETRICS
# except except : ANGIULLI F 2005 IEEE T KNOWL DATA EN LANG CL 2012 NAV RES LOG
# except except : CHAKRABORTI S 2001 J QUAL TECHNOL DAS N 2009 QUAL TECHNOL QUANT M
# except except : CHAKRABORTI S 2001 J QUAL TECHNOL EFRON B. 1993 INTRO BOOTSTRAP
# except except : CHAKRABORTI S 2001 J QUAL TECHNOL FRANK A. 2010 UCI MACHINE LEARNING
# except except : CHAKRABORTI S 2001 J QUAL TECHNOL RAO J 1992 RNEA TECHN B SER LAN
# except except : CHAKRABORTI S 2001 J QUAL TECHNOL FILIPPIDIS A 1992 FUEL
# except except : CHAKRABORTI S 2001 J QUAL TECHNOL ZOU CK 2011 TECHNOMETRICS
# except except : CHAKRABORTI S 2001 J QUAL TECHNOL LANG CL 2012 NAV RES LOG
# except except : DAS N 2009 QUAL TECHNOL QUANT M EFRON B. 1993 INTRO BOOTSTRAP
# except except : DAS N 2009 QUAL TECHNOL QUANT M FRANK A. 2010 UCI MACHINE LEARNING
# except except : DAS N 2009 QUAL TECHNOL QUANT M RAO J 1992 RNEA TECHN B SER LAN
# except except : DAS N 2009 QUAL TECHNOL QUANT M FILIPPIDIS A 1992 FUEL
# except except : DAS N 2009 QUAL TECHNOL QUANT M ZOU CK 2011 TECHNOMETRICS
# except except : DAS N 2009 QUAL TECHNOL QUANT M LANG CL 2012 NAV RES LOG
# except except : EFRON B. 1993 INTRO BOOTSTRAP FRANK A. 2010 UCI MACHINE LEARNING
# except except : EFRON B. 1993 INTRO BOOTSTRAP RAO J 1992 RNEA TECHN B SER LAN
# except except : EFRON B. 1993 INTRO BOOTSTRAP FILIPPIDIS A 1992 FUEL
# except except : EFRON B. 1993 INTRO BOOTSTRAP ZOU CK 2011 TECHNOMETRICS
# except except : EFRON B. 1993 INTRO BOOTSTRAP LANG CL 2012 NAV RES LOG
# except except : FRANK A. 2010 UCI MACHINE LEARNING RAO J 1992 RNEA TECHN B SER LAN
# except except : FRANK A. 2010 UCI MACHINE LEARNING FILIPPIDIS A 1992 FUEL
# except except : FRANK A. 2010 UCI MACHINE LEARNING ZOU CK 2011 TECHNOMETRICS
# except except : FRANK A. 2010 UCI MACHINE LEARNING LANG CL 2012 NAV RES LOG
# try: RAO J 1992 RNEA TECHN B SER LAN FILIPPIDIS A 1992 FUEL
# except except : RAO J 1992 RNEA TECHN B SER LAN ZOU CK 2011 TECHNOMETRICS
# except except : RAO J 1992 RNEA TECHN B SER LAN LANG CL 2012 NAV RES LOG
# except except : FILIPPIDIS A 1992 FUEL ZOU CK 2011 TECHNOMETRICS
# except except : FILIPPIDIS A 1992 FUEL LANG CL 2012 NAV RES LOG
# except except : ZOU CK 2011 TECHNOMETRICS LANG CL 2012 NAV RES LOG
# key :  XIAO HY 2011 SOIL SEDIMENT CONTAM val: 1
# key :  YU HL 2007 STOCH ENV RES RISK A val: 1
# key :  CHAKRABORTI S 2001 J QUAL TECHNOL val: 1
# key :  FILIPPIDIS A 1992 FUEL val: 1
# key :  VATALIS K. 2006 ENVIRON MANAGE val: 1
# key :  EFRON B. 1993 INTRO BOOTSTRAP val: 1
# key :  ADRIANO D. 2001 TRACE ELEMENTS TERRE val: 1
# key :  DAS N 2009 QUAL TECHNOL QUANT M val: 1
# key :  LANG CL 2012 NAV RES LOG val: 1
# key :  FRANK A. 2010 UCI MACHINE LEARNING val: 1
# key :  RAO J 1992 RNEA TECHN B SER LAN val: 1
# key :  ANGIULLI F 2005 IEEE T KNOWL DATA EN val: 1
# key :  ZOU CK 2011 TECHNOMETRICS val: 1
# RAO J 1992 RNEA TECHN B SER LAN
