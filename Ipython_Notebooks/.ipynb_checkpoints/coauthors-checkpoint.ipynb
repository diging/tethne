# %%
import tethne.readers as rd
filepath = "../testsuite/testin/iptraffic.txt"
wos_list = rd.wos.parse_wos(filepath)
meta_list = rd.wos.wos2meta(wos_list)

import tethne.networks as nt
coauthors = nt.authors.coauthors(meta_list, 'date','jtitle','ayjid')

for paper in meta_list:
    print paper['doi']

print "comes here"
import tethne.writers as wr
wr.graph.to_gexf(coauthors, "../testsuite/testout/coauthors_code_changed")
# Out:
# Len: 6 ['UNNIKRISHNAN', 'VADLAMANI', 'LIAO', 'CRENNE', 'GAO', 'TESSIER']
# i: 0 val 1: UNNIKRISHNAN val 2: D
# listC: inside ['UNNIKRISHNAN D']
# i: 1 val 1: VADLAMANI val 2: R
# listC: inside ['UNNIKRISHNAN D', 'VADLAMANI R']
# i: 2 val 1: LIAO val 2: Y
# listC: inside ['UNNIKRISHNAN D', 'VADLAMANI R', 'LIAO Y']
# i: 3 val 1: CRENNE val 2: J
# listC: inside ['UNNIKRISHNAN D', 'VADLAMANI R', 'LIAO Y', 'CRENNE J']
# i: 4 val 1: GAO val 2: L
# listC: inside ['UNNIKRISHNAN D', 'VADLAMANI R', 'LIAO Y', 'CRENNE J', 'GAO L']
# i: 5 val 1: TESSIER val 2: R
# listC: inside ['UNNIKRISHNAN D', 'VADLAMANI R', 'LIAO Y', 'CRENNE J', 'GAO L', 'TESSIER R']
# outside ['UNNIKRISHNAN D', 'VADLAMANI R', 'LIAO Y', 'CRENNE J', 'GAO L', 'TESSIER R']
# Len: 5 ['YANG', 'LUO', 'ZHANG', 'WANG', 'FU']
# i: 0 val 1: YANG val 2: M
# listC: inside ['YANG M']
# i: 1 val 1: LUO val 2: J
# listC: inside ['YANG M', 'LUO J']
# i: 2 val 1: ZHANG val 2: L
# listC: inside ['YANG M', 'LUO J', 'ZHANG L']
# i: 3 val 1: WANG val 2: X
# listC: inside ['YANG M', 'LUO J', 'ZHANG L', 'WANG X']
# i: 4 val 1: FU val 2: X
# listC: inside ['YANG M', 'LUO J', 'ZHANG L', 'WANG X', 'FU X']
# outside ['YANG M', 'LUO J', 'ZHANG L', 'WANG X', 'FU X']
# Len: 6 ['PEDROLA', 'RUIZ', 'VELASCO', 'CAREGLIO', 'DE DIOS', 'COMELLAS']
# i: 0 val 1: PEDROLA val 2: O
# listC: inside ['PEDROLA O']
# i: 1 val 1: RUIZ val 2: M
# listC: inside ['PEDROLA O', 'RUIZ M']
# i: 2 val 1: VELASCO val 2: L
# listC: inside ['PEDROLA O', 'RUIZ M', 'VELASCO L']
# i: 3 val 1: CAREGLIO val 2: D
# listC: inside ['PEDROLA O', 'RUIZ M', 'VELASCO L', 'CAREGLIO D']
# i: 4 val 1: DE DIOS val 2: O
# listC: inside ['PEDROLA O', 'RUIZ M', 'VELASCO L', 'CAREGLIO D', 'DE DIOS O']
# i: 5 val 1: COMELLAS val 2: J
# listC: inside ['PEDROLA O', 'RUIZ M', 'VELASCO L', 'CAREGLIO D', 'DE DIOS O', 'COMELLAS J']
# outside ['PEDROLA O', 'RUIZ M', 'VELASCO L', 'CAREGLIO D', 'DE DIOS O', 'COMELLAS J']
# Len: 4 ['KAPOOR', 'RAO', 'ARSHI', 'TRIVEDI']
# i: 0 val 1: KAPOOR val 2: H
# listC: inside ['KAPOOR H']
# i: 1 val 1: RAO val 2: G
# listC: inside ['KAPOOR H', 'RAO G']
# i: 2 val 1: ARSHI val 2: S
# listC: inside ['KAPOOR H', 'RAO G', 'ARSHI S']
# i: 3 val 1: TRIVEDI val 2: G
# listC: inside ['KAPOOR H', 'RAO G', 'ARSHI S', 'TRIVEDI G']
# outside ['KAPOOR H', 'RAO G', 'ARSHI S', 'TRIVEDI G']
# Len: 3 ['KRYNICKI', 'JAEN', 'MOCHOLI']
# i: 0 val 1: KRYNICKI val 2: K
# listC: inside ['KRYNICKI K']
# i: 1 val 1: JAEN val 2: J
# listC: inside ['KRYNICKI K', 'JAEN J']
# i: 2 val 1: MOCHOLI val 2: J
# listC: inside ['KRYNICKI K', 'JAEN J', 'MOCHOLI J']
# outside ['KRYNICKI K', 'JAEN J', 'MOCHOLI J']
# Len: 4 ['KATAYAMA', 'INOUE', 'TAKAHASHI', 'KAWAMURA']
# i: 0 val 1: KATAYAMA val 2: Y
# listC: inside ['KATAYAMA Y']
# i: 1 val 1: INOUE val 2: T
# listC: inside ['KATAYAMA Y', 'INOUE T']
# i: 2 val 1: TAKAHASHI val 2: N
# listC: inside ['KATAYAMA Y', 'INOUE T', 'TAKAHASHI N']
# i: 3 val 1: KAWAMURA val 2: R
# listC: inside ['KATAYAMA Y', 'INOUE T', 'TAKAHASHI N', 'KAWAMURA R']
# outside ['KATAYAMA Y', 'INOUE T', 'TAKAHASHI N', 'KAWAMURA R']
# Len: 5 ['APARICIO-PARDO', 'GARCIA-MANRUBIA', 'PAVON-MARINO', 'SKORIN-KAPOV', 'FURDEK']
# i: 0 val 1: APARICIO-PARDO val 2: R
# listC: inside ['APARICIO-PARDO R']
# i: 1 val 1: GARCIA-MANRUBIA val 2: B
# listC: inside ['APARICIO-PARDO R', 'GARCIA-MANRUBIA B']
# i: 2 val 1: PAVON-MARINO val 2: P
# listC: inside ['APARICIO-PARDO R', 'GARCIA-MANRUBIA B', 'PAVON-MARINO P']
# i: 3 val 1: SKORIN-KAPOV val 2: N
# listC: inside ['APARICIO-PARDO R', 'GARCIA-MANRUBIA B', 'PAVON-MARINO P', 'SKORIN-KAPOV N']
# i: 4 val 1: FURDEK val 2: M
# listC: inside ['APARICIO-PARDO R', 'GARCIA-MANRUBIA B', 'PAVON-MARINO P', 'SKORIN-KAPOV N', 'FURDEK M']
# outside ['APARICIO-PARDO R', 'GARCIA-MANRUBIA B', 'PAVON-MARINO P', 'SKORIN-KAPOV N', 'FURDEK M']
# Len: 4 ['CHEN', 'RADHAKRISHNAN', 'DHALL', 'KARABUK']
# i: 0 val 1: CHEN val 2: Y
# listC: inside ['CHEN Y']
# i: 1 val 1: RADHAKRISHNAN val 2: S
# listC: inside ['CHEN Y', 'RADHAKRISHNAN S']
# i: 2 val 1: DHALL val 2: S
# listC: inside ['CHEN Y', 'RADHAKRISHNAN S', 'DHALL S']
# i: 3 val 1: KARABUK val 2: S
# listC: inside ['CHEN Y', 'RADHAKRISHNAN S', 'DHALL S', 'KARABUK S']
# outside ['CHEN Y', 'RADHAKRISHNAN S', 'DHALL S', 'KARABUK S']
# Len: 12 ['YE', 'MA', 'WANG', 'HSUEH', 'TOTH', 'HUANG', 'MO', 'LIU', 'HAN', 'VARVARES', 'HOFT', 'PENG']
# i: 0 val 1: YE val 2: J
# listC: inside ['YE J']
# i: 1 val 1: MA val 2: C
# listC: inside ['YE J', 'MA C']
# i: 2 val 1: WANG val 2: F
# listC: inside ['YE J', 'MA C', 'WANG F']
# i: 3 val 1: HSUEH val 2: E
# listC: inside ['YE J', 'MA C', 'WANG F', 'HSUEH E']
# i: 4 val 1: TOTH val 2: K
# listC: inside ['YE J', 'MA C', 'WANG F', 'HSUEH E', 'TOTH K']
# i: 5 val 1: HUANG val 2: Y
# listC: inside ['YE J', 'MA C', 'WANG F', 'HSUEH E', 'TOTH K', 'HUANG Y']
# i: 6 val 1: MO val 2: W
# listC: inside ['YE J', 'MA C', 'WANG F', 'HSUEH E', 'TOTH K', 'HUANG Y', 'MO W']
# i: 7 val 1: LIU val 2: S
# listC: inside ['YE J', 'MA C', 'WANG F', 'HSUEH E', 'TOTH K', 'HUANG Y', 'MO W', 'LIU S']
# i: 8 val 1: HAN val 2: B
# listC: inside ['YE J', 'MA C', 'WANG F', 'HSUEH E', 'TOTH K', 'HUANG Y', 'MO W', 'LIU S', 'HAN B']
# i: 9 val 1: VARVARES val 2: M
# listC: inside ['YE J', 'MA C', 'WANG F', 'HSUEH E', 'TOTH K', 'HUANG Y', 'MO W', 'LIU S', 'HAN B', 'VARVARES M']
# i: 10 val 1: HOFT val 2: D
# listC: inside ['YE J', 'MA C', 'WANG F', 'HSUEH E', 'TOTH K', 'HUANG Y', 'MO W', 'LIU S', 'HAN B', 'VARVARES M', 'HOFT D']
# i: 11 val 1: PENG val 2: G
# listC: inside ['YE J', 'MA C', 'WANG F', 'HSUEH E', 'TOTH K', 'HUANG Y', 'MO W', 'LIU S', 'HAN B', 'VARVARES M', 'HOFT D', 'PENG G']
# outside ['YE J', 'MA C', 'WANG F', 'HSUEH E', 'TOTH K', 'HUANG Y', 'MO W', 'LIU S', 'HAN B', 'VARVARES M', 'HOFT D', 'PENG G']
# Len: 5 ['GUO', 'HOU', 'ZHENG', 'GONG', 'LV']
# i: 0 val 1: GUO val 2: L
# listC: inside ['GUO L']
# i: 1 val 1: HOU val 2: W
# listC: inside ['GUO L', 'HOU W']
# i: 2 val 1: ZHENG val 2: Z
# listC: inside ['GUO L', 'HOU W', 'ZHENG Z']
# i: 3 val 1: GONG val 2: X
# listC: inside ['GUO L', 'HOU W', 'ZHENG Z', 'GONG X']
# i: 4 val 1: LV val 2: S
# listC: inside ['GUO L', 'HOU W', 'ZHENG Z', 'GONG X', 'LV S']
# outside ['GUO L', 'HOU W', 'ZHENG Z', 'GONG X', 'LV S']
# Len: 4 ['LI', 'GU', 'YANG', 'YU']
# i: 0 val 1: LI val 2: H
# listC: inside ['LI H']
# i: 1 val 1: GU val 2: H
# listC: inside ['LI H', 'GU H']
# i: 2 val 1: YANG val 2: Y
# listC: inside ['LI H', 'GU H', 'YANG Y']
# i: 3 val 1: YU val 2: X
# listC: inside ['LI H', 'GU H', 'YANG Y', 'YU X']
# outside ['LI H', 'GU H', 'YANG Y', 'YU X']
# Len: 4 ['MUNIZ', 'TSUKAMOTO', 'TSURU', 'OIE']
# i: 0 val 1: MUNIZ val 2: A
# listC: inside ['MUNIZ A']
# i: 1 val 1: TSUKAMOTO val 2: K
# listC: inside ['MUNIZ A', 'TSUKAMOTO K']
# i: 2 val 1: TSURU val 2: M
# listC: inside ['MUNIZ A', 'TSUKAMOTO K', 'TSURU M']
# i: 3 val 1: OIE val 2: Y
# listC: inside ['MUNIZ A', 'TSUKAMOTO K', 'TSURU M', 'OIE Y']
# outside ['MUNIZ A', 'TSUKAMOTO K', 'TSURU M', 'OIE Y']
# Len: 5 ['AHMAD', 'BIANCO', 'BONETTO', 'CHIARAVIGLIO', 'IDZIKOWSKI']
# i: 0 val 1: AHMAD val 2: A
# listC: inside ['AHMAD A']
# i: 1 val 1: BIANCO val 2: A
# listC: inside ['AHMAD A', 'BIANCO A']
# i: 2 val 1: BONETTO val 2: E
# listC: inside ['AHMAD A', 'BIANCO A', 'BONETTO E']
# i: 3 val 1: CHIARAVIGLIO val 2: L
# listC: inside ['AHMAD A', 'BIANCO A', 'BONETTO E', 'CHIARAVIGLIO L']
# i: 4 val 1: IDZIKOWSKI val 2: F
# listC: inside ['AHMAD A', 'BIANCO A', 'BONETTO E', 'CHIARAVIGLIO L', 'IDZIKOWSKI F']
# outside ['AHMAD A', 'BIANCO A', 'BONETTO E', 'CHIARAVIGLIO L', 'IDZIKOWSKI F']
# Len: 4 ['JINNO', 'TAKARA', 'YONENAGA', 'HIRANO']
# i: 0 val 1: JINNO val 2: M
# listC: inside ['JINNO M']
# i: 1 val 1: TAKARA val 2: H
# listC: inside ['JINNO M', 'TAKARA H']
# i: 2 val 1: YONENAGA val 2: K
# listC: inside ['JINNO M', 'TAKARA H', 'YONENAGA K']
# i: 3 val 1: HIRANO val 2: A
# listC: inside ['JINNO M', 'TAKARA H', 'YONENAGA K', 'HIRANO A']
# outside ['JINNO M', 'TAKARA H', 'YONENAGA K', 'HIRANO A']
# Len: 3 ['HSIAO', 'SUN', 'FAN']
# i: 0 val 1: HSIAO val 2: H
# listC: inside ['HSIAO H']
# i: 1 val 1: SUN val 2: H
# listC: inside ['HSIAO H', 'SUN H']
# i: 2 val 1: FAN val 2: W
# listC: inside ['HSIAO H', 'SUN H', 'FAN W']
# outside ['HSIAO H', 'SUN H', 'FAN W']
# Len: 3 ['HUANG', 'LI', 'SVENSSON']
# i: 0 val 1: HUANG val 2: B
# listC: inside ['HUANG B']
# i: 1 val 1: LI val 2: J
# listC: inside ['HUANG B', 'LI J']
# i: 2 val 1: SVENSSON val 2: T
# listC: inside ['HUANG B', 'LI J', 'SVENSSON T']
# outside ['HUANG B', 'LI J', 'SVENSSON T']
# Len: 8 ['GELLER', 'KNORR', 'HERMANSON', 'PRIBYL', 'BENDZICK', 'MCCULLAR', 'MILLER', 'KAUFMAN']
# i: 0 val 1: GELLER val 2: M
# listC: inside ['GELLER M']
# i: 1 val 1: KNORR val 2: D
# listC: inside ['GELLER M', 'KNORR D']
# i: 2 val 1: HERMANSON val 2: D
# listC: inside ['GELLER M', 'KNORR D', 'HERMANSON D']
# i: 3 val 1: PRIBYL val 2: L
# listC: inside ['GELLER M', 'KNORR D', 'HERMANSON D', 'PRIBYL L']
# i: 4 val 1: BENDZICK val 2: L
# listC: inside ['GELLER M', 'KNORR D', 'HERMANSON D', 'PRIBYL L', 'BENDZICK L']
# i: 5 val 1: MCCULLAR val 2: V
# listC: inside ['GELLER M', 'KNORR D', 'HERMANSON D', 'PRIBYL L', 'BENDZICK L', 'MCCULLAR V']
# i: 6 val 1: MILLER val 2: J
# listC: inside ['GELLER M', 'KNORR D', 'HERMANSON D', 'PRIBYL L', 'BENDZICK L', 'MCCULLAR V', 'MILLER J']
# i: 7 val 1: KAUFMAN val 2: D
# listC: inside ['GELLER M', 'KNORR D', 'HERMANSON D', 'PRIBYL L', 'BENDZICK L', 'MCCULLAR V', 'MILLER J', 'KAUFMAN D']
# outside ['GELLER M', 'KNORR D', 'HERMANSON D', 'PRIBYL L', 'BENDZICK L', 'MCCULLAR V', 'MILLER J', 'KAUFMAN D']
# Len: 4 ['ALASAAD', 'NICANFAR', 'GOPALAKRISHNAN', 'LEUNG']
# i: 0 val 1: ALASAAD val 2: A
# listC: inside ['ALASAAD A']
# i: 1 val 1: NICANFAR val 2: H
# listC: inside ['ALASAAD A', 'NICANFAR H']
# i: 2 val 1: GOPALAKRISHNAN val 2: S
# listC: inside ['ALASAAD A', 'NICANFAR H', 'GOPALAKRISHNAN S']
# i: 3 val 1: LEUNG val 2: V
# listC: inside ['ALASAAD A', 'NICANFAR H', 'GOPALAKRISHNAN S', 'LEUNG V']
# outside ['ALASAAD A', 'NICANFAR H', 'GOPALAKRISHNAN S', 'LEUNG V']
# Len: 4 ['LEE', 'LEE', 'CHEN', 'HSU']
# i: 0 val 1: LEE val 2: J
# listC: inside ['LEE J']
# i: 1 val 1: LEE val 2: S
# listC: inside ['LEE J', 'LEE S']
# i: 2 val 1: CHEN val 2: H
# listC: inside ['LEE J', 'LEE S', 'CHEN H']
# i: 3 val 1: HSU val 2: K
# listC: inside ['LEE J', 'LEE S', 'CHEN H', 'HSU K']
# outside ['LEE J', 'LEE S', 'CHEN H', 'HSU K']
# Len: 4 ['SHAIKH', 'BLOW', 'EBERHARD', 'FOWLER']
# i: 0 val 1: SHAIKH val 2: A
# listC: inside ['SHAIKH A']
# i: 1 val 1: BLOW val 2: K
# listC: inside ['SHAIKH A', 'BLOW K']
# i: 2 val 1: EBERHARD val 2: M
# listC: inside ['SHAIKH A', 'BLOW K', 'EBERHARD M']
# i: 3 val 1: FOWLER val 2: S
# listC: inside ['SHAIKH A', 'BLOW K', 'EBERHARD M', 'FOWLER S']
# outside ['SHAIKH A', 'BLOW K', 'EBERHARD M', 'FOWLER S']
# Len: 3 ['SERROR', 'ZANG', 'BOLOT']
# i: 0 val 1: SERROR val 2: J
# listC: inside ['SERROR J']
# i: 1 val 1: ZANG val 2: H
# listC: inside ['SERROR J', 'ZANG H']
# i: 2 val 1: BOLOT val 2: J
# listC: inside ['SERROR J', 'ZANG H', 'BOLOT J']
# outside ['SERROR J', 'ZANG H', 'BOLOT J']
# Len: 3 ['FAIRHURST', 'SECCHI', 'YUN']
# i: 0 val 1: FAIRHURST val 2: G
# listC: inside ['FAIRHURST G']
# i: 1 val 1: SECCHI val 2: R
# listC: inside ['FAIRHURST G', 'SECCHI R']
# i: 2 val 1: YUN val 2: A
# listC: inside ['FAIRHURST G', 'SECCHI R', 'YUN A']
# outside ['FAIRHURST G', 'SECCHI R', 'YUN A']
# Len: 3 ['TANAKA', 'HIRANO', 'JINNO']
# i: 0 val 1: TANAKA val 2: T
# listC: inside ['TANAKA T']
# i: 1 val 1: HIRANO val 2: A
# listC: inside ['TANAKA T', 'HIRANO A']
# i: 2 val 1: JINNO val 2: M
# listC: inside ['TANAKA T', 'HIRANO A', 'JINNO M']
# outside ['TANAKA T', 'HIRANO A', 'JINNO M']
# Len: 3 ['CESPEDES', 'TAHA', 'SHEN']
# i: 0 val 1: CESPEDES val 2: S
# listC: inside ['CESPEDES S']
# i: 1 val 1: TAHA val 2: S
# listC: inside ['CESPEDES S', 'TAHA S']
# i: 2 val 1: SHEN val 2: X
# listC: inside ['CESPEDES S', 'TAHA S', 'SHEN X']
# outside ['CESPEDES S', 'TAHA S', 'SHEN X']
# Len: 4 ['KAWAMOTO', 'NISHIYAMA', 'KATO', 'KADOWAKI']
# i: 0 val 1: KAWAMOTO val 2: Y
# listC: inside ['KAWAMOTO Y']
# i: 1 val 1: NISHIYAMA val 2: H
# listC: inside ['KAWAMOTO Y', 'NISHIYAMA H']
# i: 2 val 1: KATO val 2: N
# listC: inside ['KAWAMOTO Y', 'NISHIYAMA H', 'KATO N']
# i: 3 val 1: KADOWAKI val 2: N
# listC: inside ['KAWAMOTO Y', 'NISHIYAMA H', 'KATO N', 'KADOWAKI N']
# outside ['KAWAMOTO Y', 'NISHIYAMA H', 'KATO N', 'KADOWAKI N']
# Len: 1 ['SOU']
# i: 0 val 1: SOU val 2: S
# listC: inside ['SOU S']
# outside ['SOU S']
# Len: 6 ['BAUTISTA', 'SAWHNEY', 'SHUKAIR', 'SINGH', 'GOVINDARAJU', 'SARKAR']
# i: 0 val 1: BAUTISTA val 2: J
# listC: inside ['BAUTISTA J']
# i: 1 val 1: SAWHNEY val 2: S
# listC: inside ['BAUTISTA J', 'SAWHNEY S']
# i: 2 val 1: SHUKAIR val 2: M
# listC: inside ['BAUTISTA J', 'SAWHNEY S', 'SHUKAIR M']
# i: 3 val 1: SINGH val 2: I
# listC: inside ['BAUTISTA J', 'SAWHNEY S', 'SHUKAIR M', 'SINGH I']
# i: 4 val 1: GOVINDARAJU val 2: V
# listC: inside ['BAUTISTA J', 'SAWHNEY S', 'SHUKAIR M', 'SINGH I', 'GOVINDARAJU V']
# i: 5 val 1: SARKAR val 2: S
# listC: inside ['BAUTISTA J', 'SAWHNEY S', 'SHUKAIR M', 'SINGH I', 'GOVINDARAJU V', 'SARKAR S']
# outside ['BAUTISTA J', 'SAWHNEY S', 'SHUKAIR M', 'SINGH I', 'GOVINDARAJU V', 'SARKAR S']
# Len: 5 ['HRYCEK', 'FRANEK', 'BLASZCZAK', 'DWORAK', 'HRYCEK']
# i: 0 val 1: HRYCEK val 2: E
# listC: inside ['HRYCEK E']
# i: 1 val 1: FRANEK val 2: A
# listC: inside ['HRYCEK E', 'FRANEK A']
# i: 2 val 1: BLASZCZAK val 2: E
# listC: inside ['HRYCEK E', 'FRANEK A', 'BLASZCZAK E']
# i: 3 val 1: DWORAK val 2: J
# listC: inside ['HRYCEK E', 'FRANEK A', 'BLASZCZAK E', 'DWORAK J']
# i: 4 val 1: HRYCEK val 2: A
# listC: inside ['HRYCEK E', 'FRANEK A', 'BLASZCZAK E', 'DWORAK J', 'HRYCEK A']
# outside ['HRYCEK E', 'FRANEK A', 'BLASZCZAK E', 'DWORAK J', 'HRYCEK A']
# Len: 1 ['FU']
# i: 0 val 1: FU val 2: C
# listC: inside ['FU C']
# outside ['FU C']
# Len: 7 ['CHANG', 'VENKATASUBRAMANIAN', 'WEST', 'KANNAN', 'LEE', 'LOO', 'SOKOLSKY']
# i: 0 val 1: CHANG val 2: J
# listC: inside ['CHANG J']
# i: 1 val 1: VENKATASUBRAMANIAN val 2: K
# listC: inside ['CHANG J', 'VENKATASUBRAMANIAN K']
# i: 2 val 1: WEST val 2: A
# listC: inside ['CHANG J', 'VENKATASUBRAMANIAN K', 'WEST A']
# i: 3 val 1: KANNAN val 2: S
# listC: inside ['CHANG J', 'VENKATASUBRAMANIAN K', 'WEST A', 'KANNAN S']
# i: 4 val 1: LEE val 2: I
# listC: inside ['CHANG J', 'VENKATASUBRAMANIAN K', 'WEST A', 'KANNAN S', 'LEE I']
# i: 5 val 1: LOO val 2: B
# listC: inside ['CHANG J', 'VENKATASUBRAMANIAN K', 'WEST A', 'KANNAN S', 'LEE I', 'LOO B']
# i: 6 val 1: SOKOLSKY val 2: O
# listC: inside ['CHANG J', 'VENKATASUBRAMANIAN K', 'WEST A', 'KANNAN S', 'LEE I', 'LOO B', 'SOKOLSKY O']
# outside ['CHANG J', 'VENKATASUBRAMANIAN K', 'WEST A', 'KANNAN S', 'LEE I', 'LOO B', 'SOKOLSKY O']
# Len: 5 ['RICCIARDI', 'PALMIERI', 'FIORE', 'CASTIGLIONE', 'SANTOS-BOADA']
# i: 0 val 1: RICCIARDI val 2: S
# listC: inside ['RICCIARDI S']
# i: 1 val 1: PALMIERI val 2: F
# listC: inside ['RICCIARDI S', 'PALMIERI F']
# i: 2 val 1: FIORE val 2: U
# listC: inside ['RICCIARDI S', 'PALMIERI F', 'FIORE U']
# i: 3 val 1: CASTIGLIONE val 2: A
# listC: inside ['RICCIARDI S', 'PALMIERI F', 'FIORE U', 'CASTIGLIONE A']
# i: 4 val 1: SANTOS-BOADA val 2: G
# listC: inside ['RICCIARDI S', 'PALMIERI F', 'FIORE U', 'CASTIGLIONE A', 'SANTOS-BOADA G']
# outside ['RICCIARDI S', 'PALMIERI F', 'FIORE U', 'CASTIGLIONE A', 'SANTOS-BOADA G']
# Len: 1 ['CHEN']
# i: 0 val 1: CHEN val 2: C
# listC: inside ['CHEN C']
# outside ['CHEN C']
# Len: 3 ['DAVY', 'JENNINGS', 'BOTVICH']
# i: 0 val 1: DAVY val 2: A
# listC: inside ['DAVY A']
# i: 1 val 1: JENNINGS val 2: B
# listC: inside ['DAVY A', 'JENNINGS B']
# i: 2 val 1: BOTVICH val 2: D
# listC: inside ['DAVY A', 'JENNINGS B', 'BOTVICH D']
# outside ['DAVY A', 'JENNINGS B', 'BOTVICH D']
# Len: 3 ['ZHONG', 'RAAHEMI', 'LIU']
# i: 0 val 1: ZHONG val 2: W
# listC: inside ['ZHONG W']
# i: 1 val 1: RAAHEMI val 2: B
# listC: inside ['ZHONG W', 'RAAHEMI B']
# i: 2 val 1: LIU val 2: J
# listC: inside ['ZHONG W', 'RAAHEMI B', 'LIU J']
# outside ['ZHONG W', 'RAAHEMI B', 'LIU J']
# Len: 5 ['HUANG', 'PARLIER', 'SHEN', 'LUTTY', 'VINORES']
# i: 0 val 1: HUANG val 2: H
# listC: inside ['HUANG H']
# i: 1 val 1: PARLIER val 2: R
# listC: inside ['HUANG H', 'PARLIER R']
# i: 2 val 1: SHEN val 2: J
# listC: inside ['HUANG H', 'PARLIER R', 'SHEN J']
# i: 3 val 1: LUTTY val 2: G
# listC: inside ['HUANG H', 'PARLIER R', 'SHEN J', 'LUTTY G']
# i: 4 val 1: VINORES val 2: S
# listC: inside ['HUANG H', 'PARLIER R', 'SHEN J', 'LUTTY G', 'VINORES S']
# outside ['HUANG H', 'PARLIER R', 'SHEN J', 'LUTTY G', 'VINORES S']
# Len: 3 ['NOORUZZAMAN', 'KOYAMA', 'KATSUYAMA']
# i: 0 val 1: NOORUZZAMAN val 2: M
# listC: inside ['NOORUZZAMAN M']
# i: 1 val 1: KOYAMA val 2: O
# listC: inside ['NOORUZZAMAN M', 'KOYAMA O']
# i: 2 val 1: KATSUYAMA val 2: Y
# listC: inside ['NOORUZZAMAN M', 'KOYAMA O', 'KATSUYAMA Y']
# outside ['NOORUZZAMAN M', 'KOYAMA O', 'KATSUYAMA Y']
# Len: 6 ['CHENG', 'COYLE', 'MCGARRY', 'PEDAN', 'VEYTSER', 'WHEELER']
# i: 0 val 1: CHENG val 2: B
# listC: inside ['CHENG B']
# i: 1 val 1: COYLE val 2: A
# listC: inside ['CHENG B', 'COYLE A']
# i: 2 val 1: MCGARRY val 2: S
# listC: inside ['CHENG B', 'COYLE A', 'MCGARRY S']
# i: 3 val 1: PEDAN val 2: I
# listC: inside ['CHENG B', 'COYLE A', 'MCGARRY S', 'PEDAN I']
# i: 4 val 1: VEYTSER val 2: L
# listC: inside ['CHENG B', 'COYLE A', 'MCGARRY S', 'PEDAN I', 'VEYTSER L']
# i: 5 val 1: WHEELER val 2: J
# listC: inside ['CHENG B', 'COYLE A', 'MCGARRY S', 'PEDAN I', 'VEYTSER L', 'WHEELER J']
# outside ['CHENG B', 'COYLE A', 'MCGARRY S', 'PEDAN I', 'VEYTSER L', 'WHEELER J']
# Len: 4 ['HOU', 'GUO', 'ZHENG', 'ZHANG']
# i: 0 val 1: HOU val 2: W
# listC: inside ['HOU W']
# i: 1 val 1: GUO val 2: L
# listC: inside ['HOU W', 'GUO L']
# i: 2 val 1: ZHENG val 2: Z
# listC: inside ['HOU W', 'GUO L', 'ZHENG Z']
# i: 3 val 1: ZHANG val 2: X
# listC: inside ['HOU W', 'GUO L', 'ZHENG Z', 'ZHANG X']
# outside ['HOU W', 'GUO L', 'ZHENG Z', 'ZHANG X']
# Len: 4 ['MORELL', 'VILAJOSANA', 'VICARIO', 'WATTEYNE']
# i: 0 val 1: MORELL val 2: A
# listC: inside ['MORELL A']
# i: 1 val 1: VILAJOSANA val 2: X
# listC: inside ['MORELL A', 'VILAJOSANA X']
# i: 2 val 1: VICARIO val 2: J
# listC: inside ['MORELL A', 'VILAJOSANA X', 'VICARIO J']
# i: 3 val 1: WATTEYNE val 2: T
# listC: inside ['MORELL A', 'VILAJOSANA X', 'VICARIO J', 'WATTEYNE T']
# outside ['MORELL A', 'VILAJOSANA X', 'VICARIO J', 'WATTEYNE T']
# Len: 4 ['AL-SURMI', 'OTHMAN', 'HAMID', 'ALI']
# i: 0 val 1: AL-SURMI val 2: I
# listC: inside ['AL-SURMI I']
# i: 1 val 1: OTHMAN val 2: M
# listC: inside ['AL-SURMI I', 'OTHMAN M']
# i: 2 val 1: HAMID val 2: N
# listC: inside ['AL-SURMI I', 'OTHMAN M', 'HAMID N']
# i: 3 val 1: ALI val 2: B
# listC: inside ['AL-SURMI I', 'OTHMAN M', 'HAMID N', 'ALI B']
# outside ['AL-SURMI I', 'OTHMAN M', 'HAMID N', 'ALI B']
# 10.1109/TC.2012.155
# 10.1007/s11227-012-0788-4
# None
# 10.1007/s00034-013-9568-5
# 10.1016/j.asoc.2013.07.022
# 10.1587/transcom.E96.B.2784
# 10.1016/j.osn.2013.05.001
# 10.1016/j.comnet.2013.05.012
# 10.1158/0008-5472.CAN-13-0348
# 10.1109/JLT.2013.2281117
# 10.1016/j.compeleceng.2013.08.006
# 10.1587/transcom.E96.B.2587
# 10.1364/JOCN.5.00A127
# 10.1364/JOCN.5.000A46
# 10.1002/sec.692
# 10.1007/s11277-013-1125-9
# 10.1016/j.jcyt.2013.05.022
# 10.1007/s11276-013-0559-z
# 10.1109/TC.2012.107
# 10.1049/iet-com.2012.0686
# 10.1016/j.comnet.2013.04.011
# 10.1002/sat.1026
# 10.1109/LCOMM.2013.070913.130580
# 10.1109/TVT.2013.2252931
# 10.1109/TVT.2013.2256812
# 10.1109/TVT.2013.2255899
# None
# 10.1007/s00296-012-2393-5
# 10.1007/s11277-013-1055-6
# 10.1109/JSYST.2012.2221856
# 10.1016/j.mcm.2012.12.004
# 10.1016/j.future.2012.03.026
# 10.1007/s10922-012-9243-3
# 10.1007/s12083-012-0147-5
# 10.1371/journal.pone.0071808
# 10.1016/j.comnet.2013.04.010
# 10.1109/TWC.2013.052613.130019
# 10.1364/JOCN.5.000858
# 10.1002/ett.2650
# 10.1007/s11276-012-0535-z
# comes here

# %%
import networkx as nx
G=nx.Graph()   # or DiGraph, MultiGraph, MultiDiGraph, etc
G.add_path([0,1,2,3])
#G.add_path([10,11,12],weight=7)
