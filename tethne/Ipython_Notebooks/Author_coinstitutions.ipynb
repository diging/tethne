# %%
import tethne.readers as rd
filepath = "/Users/ramki/tethne/tethne/testsuite/testin/authorinstitutions_test.txt"
wos_list = rd.parse_wos(filepath)


print ' wos_list is done '

for c1 in wos_list:
    print c1['C1'],'\n'

meta_list=rd.wos2meta(wos_list)    

for paper in meta_list:
    print paper['institutions'],'\n'
    
import tethne.networks as nt
author_coinst = nt.nx_author_coinstitution(meta_list, 2) 

import tethne.writers as wr
wr.to_gexf(author_coinst, "/Users/ramki/output/author_coinstitutions_2sharedfinal")
# Out:
#  wos_list is done
# ['[Wu, Zongda; Lu, Chenglang] Wenzhou Univ, Wenzhou 325035, Peoples R China.', '[Wu, Zongda; Chen, Enhong] Univ Sci & Technol China, Hefei 230026, Anhui, Peoples R China.', '[Xu, Guandong] Univ Technol Sydney, Sydney, NSW 2007, Australia.', '[Lu, Chenglang] Northwestern Polytech Univ, Xian 710072, Peoples R China.', '[Zhang, Yanchun] Victoria Univ, Melbourne, Vic 8001, Australia.', '[Zhang, Hong] Inst Sci & Technol Informat Zhejiang Prov, Hangzhou 310006, Zhejiang, Peoples R China.']
#
# ['[Acampora, Giovanni] Eindhoven Univ Technol, Sch Ind Engn, NL-5600 MB Eindhoven, Netherlands.', '[Loia, Vincenzo; Vitiello, Autilia] Univ Salerno, Dept Comp Sci, I-84084 Fisciano, Italy.']
#
# None
#
# ['Natl Chung Cheng Univ, Dept Business Adm, Chiayi, Taiwan.']
#
# ...

# %%
for paper in meta_list:
    print paper['institutions']
# Out:
# {'ZHANG, YC': ['Victoria Univ'], 'WU, ZD': ['Wenzhou Univ', 'Univ Sci & Technol China'], 'LU, CL': ['Wenzhou Univ', 'Northwestern Polytech Univ'], 'CHEN, EH': ['Univ Sci & Technol China'], 'ZHANG, H': ['Inst Sci & Technol Informat Zhejiang Prov'], 'XU, GD': ['Univ Technol Sydney']}
# {'VITIELLO, A': ['Univ Salerno'], 'LOIA, V': ['Univ Salerno'], 'ACAMPORA, G': ['Eindhoven Univ Technol']}
# None
# {'Huang, TCK': ['Natl Chung Cheng Univ']}

# %%
import tethne.readers as rd
filepath = "/Users/ramki/tethne/tethne/testsuite/testin/no_c1_field.txt"
wos_list = rd.parse_wos(filepath)


meta_list=rd.wos2meta(wos_list)    
print '\n', meta_list
# Out:
# [<tethne.data.Paper instance at 0x110b0a830>, <tethne.data.Paper instance at 0x110b61b90>]

# %%
A =dict()
B =dict()

A= {'A1' : 'I1', 'A2' : 'I1', 'A3' : 'I1','A4' : 'I1'}
B= {'A1' : 'I2', 'A2' : 'I3', 'A5' : 'I2','A8' : 'I5'}
print A,B

for key,val in A.iteritems(),B.iteritems() :
    if A[key] == B[key] :
        print 'yes'
    else :
        print 'no'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-14ad61900e45> in <module>()
#       6 print A,B
#       7
# ----> 8 for key,val in A.iteritems(),B.iteritems() :
#       9     if A[key] == B[key] :
#      10         print 'yes'
#
# ValueError: too many values to unpack
# {'A1': 'I1', 'A3': 'I1', 'A2': 'I1', 'A4': 'I1'} {'A1': 'I2', 'A8': 'I5', 'A2': 'I3', 'A5': 'I2'}

# %%
fruit_available = {'apples': 25, 'oranges': 0, 'mango': 12, 'pineapple': 0 }

my_satchel = {'apples': 1, 'oranges': 0, 'kiwi': 13 }

available = set(fruit_available.keys())
satchel = set(my_satchel.keys())

# fruit not in your satchel, but that is available
print available.difference(satchel)
# Out:
# set(['mango', 'pineapple'])

# %%
import tethne.readers as rd
filepath = "/Users/ramki/tethne/tethne/testsuite/testin/no_c1_field.txt"
wos_list = rd.parse_wos(filepath)

# %%
 au=['Hristoskova, Anna', ' Volckaert, Bruno', ' De Turck, Filip']
 ins = [ 'ASU']
    
 au_ins= dict()   
 #print au
 #print ins   
    
 for i in au:
     for a in ins:   
        
        try:
            au_ins[i].append(a)
            
        except KeyError,AttributeError:
            au_ins[i] = a
            
 print au_ins
# Out:
# {' De Turck, Filip': 'ASU', ' Volckaert, Bruno': 'ASU', 'Hristoskova, Anna': 'ASU'}

# %%
list1=[{'doi': '10.1016/j.neucom.2013.04.018', 'aulast': ['WU', 'XU', 'LU', 'CHEN', 'ZHANG', 'ZHANG'], 
        'country': None, 'wosid': 'WOS:000324847100057', 'ayjid': 'WU Z 2013 NEUROCOMPUTING', 
        'institutions': {'ZHANG, YC': ['Victoria Univ'], 
                         'WU, ZD': ['Wenzhou Univ', 'Univ Sci & Technol China'], 
                         'LU, CL': ['Wenzhou Univ', 'Northwestern Polytech Univ'], 
                         'CHEN, EH': ['Univ Sci & Technol China'], 
                         'ZHANG, H': ['Inst Sci & Technol Informat Zhejiang Prov'], 
                         'XU, GD': ['Univ Technol Sydney']}} ]  

l2= [ 'a', 'c' , 'd']


for i in xrange(len(l2)):
    print l2
    

   
myvalues = [i['institutions'] for i in list1 if 'institutions' in i]
print myvalues,len(l2)
# Out:
# ['a', 'c', 'd']
# ['a', 'c', 'd']
# ['a', 'c', 'd']
# [{'ZHANG, YC': ['Victoria Univ'], 'WU, ZD': ['Wenzhou Univ', 'Univ Sci & Technol China'], 'LU, CL': ['Wenzhou Univ', 'Northwestern Polytech Univ'], 'CHEN, EH': ['Univ Sci & Technol China'], 'ZHANG, H': ['Inst Sci & Technol Informat Zhejiang Prov'], 'XU, GD': ['Univ Technol Sydney']}] 3

# %%
\
list1= [{'doi': '10.1016/j.neucom.2013.04.018', 'aulast': ['WU', 'XU', 'LU', 'CHEN', 'ZHANG', 'ZHANG'], 'country': None, 'wosid': 'WOS:000324847100057', 'ayjid': 'WU Z 2013 NEUROCOMPUTING', 'volume': '120', 'citations': [{'doi': None, 'aulast': 'Anagnostopoulos', 'country': None, 'wosid': None, 'ayjid': 'Anagnostopoulos A. 2007 CIKM 07', 'volume': '331', 'citations': None, 'jtitle': 'CIKM 07', 'atitle': None, 'date': 2007, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 'A.'}, {'doi': None, 'aulast': 'Boyd', 'country': None, 'wosid': None, 'ayjid': 'Boyd S. 2004 CONVEX OPTIMIZATION', 'volume': None, 'citations': None, 'jtitle': 'CONVEX OPTIMIZATION', 'atitle': None, 'date': 2004, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 'S.'}, {'doi': None, 'aulast': 'Broder', 'country': None, 'wosid': None, 'ayjid': 'Broder A. 2007 SIGIR 07', 'volume': '559', 'citations': None, 'jtitle': 'SIGIR 07', 'atitle': None, 'date': 2007, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 
 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 'AL'}, {'doi': None, 'aulast': 'Gracia', 'country': None, 'wosid': None, 'ayjid': 'Gracia J. 2011 P 6 INT WORKSH ONT M', 'volume': None, 'citations': None, 'jtitle': 'P 6 INT WORKSH ONT M', 'atitle': None, 'date': 2011, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 'J.'}, {'doi': '10.1006/knac.1993.1008', 'aulast': 'GRUBER', 'country': None, 'wosid': None, 'ayjid': 'GRUBER TR 1993 KNOWL ACQUIS', 'volume': '5', 'citations': None, 'jtitle': 'KNOWL ACQUIS', 'atitle': None, 'date': 1993, 'epage': None, 'pmid': None, 'spage': '199', 'issue': None, 'institution': None, 'auinit': 'TR'}, {'doi': None, 'aulast': 'Hamdi', 'country': None, 'wosid': None, 'ayjid': 'Hamdi F. 2010 P 5 INT WORKSH ONT M', 'volume': None, 'citations': None, 'jtitle': 'P 5 INT WORKSH ONT M', 'atitle': None, 'date': 2010, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 'F.'}, {'doi': '10.1002/int.10091', 'aulast': 'Herrera', 'country': None, 'wosid': None, 'ayjid': 'Herrera F 2003 INT J INTELL SYST', 'volume': '18', 'citations': None, 'jtitle': 'INT J INTELL SYST', 'atitle': None, 'date': 2003, 'epage': None, 'pmid': None, 'spage': '309', 'issue': None, 'institution': None, 'auinit': 'F'}, {'doi': None, 'aulast': 'HOLM', 'country': None, 'wosid': None, 'ayjid': 'HOLM S 1979 SCAND J STAT', 'volume': '6', 'citations': None, 'jtitle': 'SCAND J STAT', 'atitle': None, 'date': 1979, 'epage': None, 'pmid': None, 'spage': '65', 'issue': None, 'institution': None, 'auinit': 'S'}, {'doi': None, 'aulast': 'Hu', 'country': None, 'wosid': None, 'ayjid': 'Hu W. 2010 P 5 INT WORKSH ONT M', 'volume': None, 'citations': None, 'jtitle': 'P 5 INT WORKSH ONT M', 'atitle': None, 'date': 2010, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 'W.'}, {'doi': '10.1016/j.websem.2009.04.001', 'aulast': 'Jean-Mary', 'country': None, 'wosid': None, 'ayjid': 'Jean-Mary YR 2009 J WEB SEMANT', 'volume': '7', 'citations': None, 'jtitle': 'J WEB SEMANT', 'atitle': None, 'date': 2009, 'epage': None, 'pmid': None, 'spage': '235', 'issue': None, 'institution': None, 'auinit': 'YR'}, {'doi': None, 'aulast': 'Kirkpatrick', 'country': None, 'wosid': None, 'ayjid': 'Kirkpatrick S. 1982 9355 IBM RC', 'volume': None, 'citations': None, 'jtitle': '9355 IBM RC', 'atitle': None, 'date': 1982, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 'S.'}, {'doi': '10.1109/TEVC.2005.850260', 'aulast': 'Krasnogor', 'country': None, 'wosid': None, 'ayjid': 'Krasnogor N 2005 IEEE T EVOLUT COMPUT', 'volume': '9', 'citations': None, 'jtitle': 'IEEE T EVOLUT COMPUT', 'atitle': None, 'date': 2005, 'epage': None, 'pmid': None, 'spage': '474', 'issue': None, 'institution': None, 'auinit': 'N'}, {'doi': None, 'aulast': 'Levenstein', 'country': None, 'wosid': None, 'ayjid': 'Levenstein I. 1966 CYBERNETICS CONTROL', 'volume': '10', 'citations': None, 'jtitle': 'CYBERNETICS CONTROL', 'atitle': None, 'date': 1966, 'epage': None, 'pmid': None, 'spage': '707', 'issue': None, 'institution': None, 'auinit': 'I.'}, {'doi': None, 'aulast': 'Madhavan', 'country': None, 'wosid': None, 'ayjid': 'Madhavan J. 2001 P 27 INT C VER LARG', 'volume': None, 'citations': None, 'jtitle': 'P 27 INT C VER LARG', 'atitle': None, 'date': 2001, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 'J.'}, {'doi': None, 'aulast': 'Martinez-Gil', 'country': None, 'wosid': None, 'ayjid': 'Martinez-Gil J. 2008 CEUR WORKSHOP P', 'volume': '419', 'citations': None, 'jtitle': 'CEUR WORKSHOP P', 'atitle': None, 'date': 2008, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 'J.'}, {'doi': None, 'aulast': 'Moscato', 'country': None, 'wosid': None, 'ayjid': 'Moscato P. 1989 826 CALT CONC COMP P', 'volume': '826', 'citations': None, 'jtitle': '826 CALT CONC COMP P', 'atitle': None, 'date': 1989, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 'P.'}, {'doi': None, 'aulast': 'Nguyen', 'country': None, 'wosid': None, 'ayjid': 'Nguyen QH 2007 IEEE C EVOL COMPUTAT', 'volume': '2390', 'citations': None, 'jtitle': 'IEEE C EVOL COMPUTAT', 'atitle': None, 'date': 2007, 'epage': None, 'pmid': None, 'spage': 'OI 10.1109/CEC.2007.4424770', 'issue': None, 'institution': None, 'auinit': 'QH'}, {'doi': None, 'aulast': 'Noessner', 'country': None, 'wosid': None, 'ayjid': 'Noessner J. 2010 P 5 INT WORKSH ONT M', 'volume': None, 'citations': None, 'jtitle': 'P 5 INT WORKSH ONT M', 'atitle': None, 'date': 2010, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 'J.'}, {'doi': None, 'aulast': 'Noy', 'country': None, 'wosid': None, 'ayjid': 'Noy NF 2000 SEVENTEENTH NATIONAL CONFERENCE ON ARTIFICIAL INTELLIGENCE (AAAI-2001) / TWELFTH INNOVATIVE APPLICATIONS OF ARTIFICIAL INTELLIGENCE CONFERENCE (IAAI-2000)', 'volume': '450', 'citations': None, 'jtitle': 'SEVENTEENTH NATIONAL CONFERENCE ON ARTIFICIAL INTELLIGENCE (AAAI-2001) / TWELFTH INNOVATIVE APPLICATIONS OF ARTIFICIAL INTELLIGENCE CONFERENCE (IAAI-2000)', 'atitle': None, 'date': 2000, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 'NF'}, {'doi': None, 'aulast': 'Powell', 'country': None, 'wosid': None, 'ayjid': 'Powell M.J.D. 1964 COMPUT J', 'volume': '7', 'citations': None, 'jtitle': 'COMPUT J', 'atitle': None, 'date': 1964, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 'M.J.D.'}, {'doi': None, 'aulast': 'Quix', 'country': None, 'wosid': None, 'ayjid': 'Quix C. 2010 P 5 INT WORKSH ONT M', 'volume': None, 'citations': None, 'jtitle': 'P 5 INT WORKSH ONT M', 'atitle': None, 'date': 2010, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 'C.'}, {'doi': '10.1007/s007780100057', 'aulast': 'Rahm', 'country': None, 'wosid': None, 'ayjid': 'Rahm E 2001 VLDB J', 'volume': '10', 'citations': None, 'jtitle': 'VLDB J', 'atitle': None, 'date': 2001, 'epage': None, 'pmid': None, 'spage': '334', 'issue': None, 'institution': None, 'auinit': 'E'}, {'doi': '10.1016/0306-4573(88)90021-0', 'aulast': 'SALTON', 'country': None, 'wosid': None, 'ayjid': 'SALTON G 1988 INFORM PROCESS MANAG', 'volume': '24', 'citations': None, 'jtitle': 'INFORM PROCESS MANAG', 'atitle': None, 'date': 1988, 'epage': None, 'pmid': None, 'spage': '513', 'issue': None, 'institution': None, 'auinit': 'G'}, {'doi': '10.1145/361219.361220', 'aulast': 'SALTON', 'country': None, 'wosid': None, 'ayjid': 'SALTON G 1975 COMMUN ACM', 'volume': '18', 'citations': None, 'jtitle': 'COMMUN ACM', 'atitle': None, 'date': 1975, 'epage': None, 'pmid': None, 'spage': '613', 'issue': None, 'institution': None, 'auinit': 'G'}, {'doi': None, 'aulast': 'Saruladha', 'country': None, 'wosid': None, 'ayjid': 'Saruladha K. 2011 INT J COMPUTER APPL', 'volume': '34', 'citations': None, 'jtitle': 'INT J COMPUTER APPL', 'atitle': None, 'date': 2011, 'epage': None, 'pmid': None, 'spage': '14', 'issue': None, 'institution': None, 'auinit': 'K.'}, {'doi': None, 'aulast': 'Sheskin', 'country': None, 'wosid': None, 'ayjid': 'Sheskin D.J. 2000 HDB PARAMETRIC NONPA', 'volume': None, 'citations': None, 'jtitle': 'HDB PARAMETRIC NONPA', 'atitle': None, 'date': 2000, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 'D.J.'}, {'doi': '10.1109/TKDE.2011.253', 'aulast': 'Shvaiko', 'country': None, 'wosid': None, 'ayjid': 'Shvaiko P 2013 IEEE T KNOWL DATA EN', 'volume': '25', 'citations': None, 'jtitle': 'IEEE T KNOWL DATA EN', 'atitle': None, 'date': 2013, 'epage': None, 'pmid': None, 'spage': '158', 'issue': None, 'institution': None, 'auinit': 'P'}, {'doi': None, 'aulast': 'Shvaiko', 'country': None, 'wosid': None, 'ayjid': 'Shvaiko P. 2004 P MEAN COORD NEG WOR', 'volume': None, 'citations': None, 'jtitle': 'P MEAN COORD NEG WOR', 'atitle': None, 'date': 2004, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 'P.'}, {'doi': None, 'aulast': 'Stoilos', 'country': None, 'wosid': None, 'ayjid': 'Stoilos G. 2005 P 4 INT SEM WEB C IS', 'volume': '623', 'citations': None, 'jtitle': 'P 4 INT SEM WEB C IS', 'atitle': None, 'date': 2005, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 'G.'}, {'doi': None, 'aulast': 'Tang', 'country': None, 'wosid': None, 'ayjid': 'Tang J. 2007 SOFT COMPUT', 'volume': '11', 'citations': None, 'jtitle': 'SOFT COMPUT', 'atitle': None, 'date': 2007, 'epage': None, 'pmid': None, 'spage': '957', 'issue': None, 'institution': None, 'auinit': 'J.'}, {'doi': '10.1016/j.ins.2010.08.021', 'aulast': 'Ting', 'country': None, 'wosid': None, 'ayjid': 'Ting CK 2010 INFORM SCIENCES', 'volume': '180', 'citations': None, 'jtitle': 'INFORM SCIENCES', 'atitle': None, 'date': 2010, 'epage': None, 'pmid': None, 'spage': '4818', 'issue': None, 'institution': None, 'auinit': 'CK'}, {'doi': None, 'aulast': 'van', 'country': None, 'wosid': None, 'ayjid': 'van Rijsbergen 1979 INFORM RETRIEVAL', 'volume': None, 'citations': None, 'jtitle': 'INFORM RETRIEVAL', 'atitle': None, 'date': 1979, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 'Rijsbergen'}, {'doi': None, 'aulast': 'Vazquez', 'country': None, 'wosid': None, 'ayjid': 'Vazquez Naya 2010 SOFT COMPUTING METHO', 'volume': '240', 'citations': None, 'jtitle': 'SOFT COMPUTING METHO', 'atitle': None, 'date': 2010, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 'Naya'}, {'doi': None, 'aulast': 'Wang', 'country': None, 'wosid': None, 'ayjid': 'Wang J. 2006 P IEEE AS PAC C SERV', 'volume': None, 'citations': None, 'jtitle': 'P IEEE AS PAC C SERV', 'atitle': None, 'date': 2006, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 'J.'}, {'doi': None, 'aulast': 'Wang', 'country': None, 'wosid': None, 'ayjid': 'Wang Z. 2010 P 5 INT WORKSH ONT M', 'volume': None, 'citations': None, 'jtitle': 'P 5 INT WORKSH ONT M', 'atitle': None, 'date': 2010, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 'Z.'}, {'doi': None, 'aulast': 'Wei', 'country': None, 'wosid': None, 'ayjid': 'Wei W. 2010 P 5 INT WORKSH ONT M', 'volume': None, 'citations': None, 'jtitle': 'P 5 INT WORKSH ONT M', 'atitle': None, 'date': 2010, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 'W.'}, {'doi': '10.1016/j.ins.2010.10.001', 'aulast': 'Wen', 'country': None, 'wosid': None, 'ayjid': 'Wen Y 2011 INFORM SCIENCES', 'volume': '181', 'citations': None, 'jtitle': 'INFORM SCIENCES', 'atitle': None, 'date': 2011, 'epage': None, 'pmid': None, 'spage': '567', 'issue': None, 'institution': None, 'auinit': 'Y'}, {'doi': None, 'aulast': 'Winkler', 'country': None, 'wosid': None, 'ayjid': 'Winkler W. 1999 TECHNICAL REPORT', 'volume': None, 'citations': None, 'jtitle': 'TECHNICAL REPORT', 'atitle': None, 'date': 1999, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 'W.'}, {'doi': None, 'aulast': 'Xu', 'country': None, 'wosid': None, 'ayjid': 'Xu P. 2010 P 5 INT WORKSH ONT M', 'volume': None, 'citations': None, 'jtitle': 'P 5 INT WORKSH ONT M', 'atitle': None, 'date': 2010, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 'P.'}], 'jtitle': 'INFORMATION SCIENCES', 'address': None, 'atitle': 'Enhancing ontology alignment through a memetic aggregation of similarity measures', 'date': 2013, 'epage': '20', 'pmid': None, 'spage': '1', 'issue': None, 'institution': None, 'auinit': ['G', 'V', 'A']}] 
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  
for i in xrange(len(list1)):                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 
    list2 = (ins for ins in list1 if 'institutions' in ins)
    print list2, len(list1)
# Out:
# <generator object <genexpr> at 0x10444fa00> 2
# <generator object <genexpr> at 0x10444fb40> 2

# %%
import tethne.readers as rd
filepath = "/Users/ramki/tethne/tethne/testsuite/testin/authorinstitutions_test.txt"
wos_list = rd.parse_wos(filepath)

for wos in wos_list:
    print wos,'\n'
print ' am done '
meta_list=rd.wos2meta(wos_list)    

print meta_list ,'\n'

print ' meta is done'


author_institutions = {}  # keys: author names, values: list of institutions


for paper in meta_list:
    for key, value in paper['institutions'].iteritems():
        try:
            author_institutions[key] += value
        except KeyError:
            author_institutions[key] = value
            
authors = author_institutions.keys()
for i in xrange(len(authors)):
    for x in xrange(len(authors)):
        if i != x:
            overlap = set(author_institutions[authors[i]]) & set(author_institutions[authors[x]])
            if len(overlap) > 0:
                print authors[i] + "->" + authors[x]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-de1b7abedbab> in <module>()
#      17
#      18 for paper in meta_list:
# ---> 19     for key, value in paper['institutions'].iteritems():
#      20         try:
#      21             author_institutions[key] += value
#
# AttributeError: 'NoneType' object has no attribute 'iteritems'
# ...

# %%
import tethne.readers as rd
filepath = "/Users/ramki/tethne/tethne/testsuite/testin/instituitions_2_types_input.txt"
wos_list = rd.parse_wos(filepath)

for wos in wos_list:
    print wos,'\n'
print ' am done '
meta_list=rd.wos2meta(wos_list)    

for meta in meta_list:
    print meta , '\n'
    
import tethne.networks as nt
author_coinst = nt.nx_author_coinstitution(meta_list, 1) 

import tethne.writers as wr
wr.to_gexf(author_coinst, "/Users/ramki/tethne/tethne/output/author_coinstitutions")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-1a81668e98ec> in <module>()
#      12
#      13 import tethne.networks as nt
# ---> 14 author_coinst = nt.nx_author_coinstitution(meta_list, 1)
#      15
#      16 import tethne.writers as wr
#
# /Users/ramki/tethne/tethne/networks.py in nx_author_coinstitution(meta_list, threshold)
#     584     authors = author_institutions.keys()
#     585     for i in xrange(len(authors)):
# --> 586         coinstitution.add_node(author[i])
#     587         for x in xrange(len(authors)):
#     588             if i != x:
#
# NameError: global name 'author' is not defined
# ...

# %%
dic = {'LA': 'English', 
    'UT': 'WOS:000325041400001', 
        'PY': 2013, 'ID': ['DESIGN ISSUES', ' ALGORITHM', ' TAXONOMY', ' MODEL'],
                'PA': '360 PARK AVE SOUTH, NEW YORK, NY 10010-1710 USA', 'SO': 'INFORMATION SCIENCES', 'Z9': '0', 'PD': 'NOV 20', 'TI': 'Enhancing ontology alignment through a memetic aggregation of similarity measures', 'SC': 'Computer Science', 
                'BP': '1', 'C1': ['[Acampora, Giovanni] Eindhoven Univ Technol, Sch Ind Engn, NL-5600 MB Eindhoven, Netherlands.', '[Loia, Vincenzo; Vitiello, Autilia] Univ Salerno, Dept Comp Sci, I-84084 Fisciano, Italy.'], 
                                                'NR': '57', 'TC': '0', 'SN': '0020-0255'}


dic2 = {'LA': 'English', 
    'UT': 'WOS:000325041400001', 
        'PY': 2013, 'ID': ['DESIGN ISSUES', ' ALGORITHM', ' TAXONOMY', ' MODEL'],
                'PA': '360 PARK AVE SOUTH, NEW YORK, NY 10010-1710 USA', 'SO': 'INFORMATION SCIENCES', 'Z9': '0', 'PD': 'NOV 20', 'TI': 'Enhancing ontology alignment through a memetic aggregation of similarity measures', 'SC': 'Computer Science', 
                'BP': '1', 'C1': ['[Acamporaasdad, Giovanni] Eindhoven Univ Technol, Sch Ind Engn, NL-5600 MB Eindhoven, Netherlands.', '[Loia, Vincenzo; Vitiello, Autilia] Univ Salerno, Dept Comp Sci, I-84084 Fisciano, Italy.'], 
                                                'NR': '57', 'TC': '0', 'SN': '0020-0255'}
dict3 = dic + dic2 

print dict3

#print dic

for key,val in dic.iteritems():
    print key,val
    
authors = dic.keys()
print authors

for i in xrange(len(authors)):
    print i 
    print authors[i]
    for j in xrange(len(authors)):
        print j
        print authors[j]
        
        
authors
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fd8d6aa64d65> in <module>()
#      13                 'BP': '1', 'C1': ['[Acamporaasdad, Giovanni] Eindhoven Univ Technol, Sch Ind Engn, NL-5600 MB Eindhoven, Netherlands.', '[Loia, Vincenzo; Vitiello, Autilia] Univ Salerno, Dept Comp Sci, I-84084 Fisciano, Italy.'],
#      14                                                 'NR': '57', 'TC': '0', 'SN': '0020-0255'}
# ---> 15 dict3 = dic1 + dic2
#      16
#      17 print dict3
#
# NameError: name 'dic1' is not defined
