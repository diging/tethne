# %%
import tethne.readers as rd
filepath = "/Users/ramki/tethne/tethne/testsuite/testin/semantic_web.txt"
wos_list = rd.parse_wos(filepath)


meta_list=rd.wos2meta(wos_list)    
#print 'wos_1'
for meta in meta_list:
 print meta
# Out:
# comes in readers.parsewos - V6
#
#  c1_str : [Hristoskova, Anna; Volckaert, Bruno; De Turck, Filip] Ghent Univ IBBT, Dept Informat Technol, B-9050 Ghent, Belgium.
#
#  match  found :  ['Hristoskova, Anna; Volckaert, Bruno; De Turck, Filip']
# authors_inst_list: ['[Hristoskova, Anna; Volckaert, Bruno; De Turck, Filip', ' Ghent Univ IBBT, Dept Informat Technol, B-9050 Ghent, Belgium.'] match ['Hristoskova, Anna; Volckaert, Bruno; De Turck, Filip']
#
#  split_name_tokens :  ['Hristoskova, Anna', ' Volckaert, Bruno', ' De Turck, Filip']
# institution GhentUnivIBBT
#
#  Comes in try block
# each_author Hristoskova, Anna ins G
#
#  comes in catch block
# inst_dict {'Hristoskova, Anna': 'G'}
#
#  c1_str : [Sun, Fuming; Wang, Xueming; Wang, Dongxia] Liaoning Univ Technol, Jinzhou 121001, Peoples R China.
#
#  match  found :  ['Sun, Fuming; Wang, Xueming; Wang, Dongxia']
# authors_inst_list: ['[Sun, Fuming; Wang, Xueming; Wang, Dongxia', ' Liaoning Univ Technol, Jinzhou 121001, Peoples R China.'] match ['Sun, Fuming; Wang, Xueming; Wang, Dongxia']
#
#  split_name_tokens :  ['Sun, Fuming', ' Wang, Xueming', ' Wang, Dongxia']
# institution LiaoningUnivTechnol
#
#  c1_str : [Li, Haojie] Dalian Univ Technol, Dalian 116024, Peoples R China.
#
#  match  found :  ['Li, Haojie']
# authors_inst_list: ['[Li, Haojie', ' Dalian Univ Technol, Dalian 116024, Peoples R China.'] match ['Li, Haojie']
#
#  split_name_tokens :  ['Li, Haojie']
# institution DalianUnivTechnol
#
#  c1_str : [Zhao, Yinghai] China Aerosp Sci Ind Corp, Res Inst 35, Beijing 100013, Peoples R China.
#
#  match  found :  ['Zhao, Yinghai']
# authors_inst_list: ['[Zhao, Yinghai', ' China Aerosp Sci Ind Corp, Res Inst 35, Beijing 100013, Peoples R China.'] match ['Zhao, Yinghai']
#
#  split_name_tokens :  ['Zhao, Yinghai']
# institution ChinaAerospSciIndCorp
#
#  Comes in try block
# each_author Zhao, Yinghai ins C
#
#  comes in catch block
# inst_dict {'Zhao, Yinghai': 'C'}
#
#  c1_str : [Wu, Zongda; Lu, Chenglang] Wenzhou Univ, Wenzhou 325035, Peoples R China.
#
#  match  found :  ['Wu, Zongda; Lu, Chenglang']
# authors_inst_list: ['[Wu, Zongda; Lu, Chenglang', ' Wenzhou Univ, Wenzhou 325035, Peoples R China.'] match ['Wu, Zongda; Lu, Chenglang']
#
#  split_name_tokens :  ['Wu, Zongda', ' Lu, Chenglang']
# institution WenzhouUniv
#
#  c1_str : [Wu, Zongda; Chen, Enhong] Univ Sci & Technol China, Hefei 230026, Anhui, Peoples R China.
#
#  match  found :  ['Wu, Zongda; Chen, Enhong']
# authors_inst_list: ['[Wu, Zongda; Chen, Enhong', ' Univ Sci & Technol China, Hefei 230026, Anhui, Peoples R China.'] match ['Wu, Zongda; Chen, Enhong']
#
#  split_name_tokens :  ['Wu, Zongda', ' Chen, Enhong']
# institution UnivSci&TechnolChina
#
#  c1_str : [Xu, Guandong] Univ Technol Sydney, Sydney, NSW 2007, Australia.
#
#  match  found :  ['Xu, Guandong']
# authors_inst_list: ['[Xu, Guandong', ' Univ Technol Sydney, Sydney, NSW 2007, Australia.'] match ['Xu, Guandong']
#
#  split_name_tokens :  ['Xu, Guandong']
# institution UnivTechnolSydney
#
#  c1_str : [Lu, Chenglang] Northwestern Polytech Univ, Xian 710072, Peoples R China.
#
#  match  found :  ['Lu, Chenglang']
# authors_inst_list: ['[Lu, Chenglang', ' Northwestern Polytech Univ, Xian 710072, Peoples R China.'] match ['Lu, Chenglang']
#
#  split_name_tokens :  ['Lu, Chenglang']
# institution NorthwesternPolytechUniv
#
#  c1_str : [Zhang, Yanchun] Victoria Univ, Melbourne, Vic 8001, Australia.
#
#  match  found :  ['Zhang, Yanchun']
# authors_inst_list: ['[Zhang, Yanchun', ' Victoria Univ, Melbourne, Vic 8001, Australia.'] match ['Zhang, Yanchun']
#
#  split_name_tokens :  ['Zhang, Yanchun']
# institution VictoriaUniv
#
#  c1_str : [Zhang, Hong] Inst Sci & Technol Informat Zhejiang Prov, Hangzhou 310006, Zhejiang, Peoples R China.
#
#  match  found :  ['Zhang, Hong']
# authors_inst_list: ['[Zhang, Hong', ' Inst Sci & Technol Informat Zhejiang Prov, Hangzhou 310006, Zhejiang, Peoples R China.'] match ['Zhang, Hong']
#
#  split_name_tokens :  ['Zhang, Hong']
# institution InstSci&TechnolInformatZhejiangProv
#
#  Comes in try block
# each_author Zhang, Hong ins I
#
#  comes in catch block
# inst_dict {'Zhang, Hong': 'I'}
#
#  c1_str : [Acampora, Giovanni] Eindhoven Univ Technol, Sch Ind Engn, NL-5600 MB Eindhoven, Netherlands.
#
#  match  found :  ['Acampora, Giovanni']
# authors_inst_list: ['[Acampora, Giovanni', ' Eindhoven Univ Technol, Sch Ind Engn, NL-5600 MB Eindhoven, Netherlands.'] match ['Acampora, Giovanni']
#
#  split_name_tokens :  ['Acampora, Giovanni']
# institution EindhovenUnivTechnol
#
#  c1_str : [Loia, Vincenzo; Vitiello, Autilia] Univ Salerno, Dept Comp Sci, I-84084 Fisciano, Italy.
#
#  match  found :  ['Loia, Vincenzo; Vitiello, Autilia']
# authors_inst_list: ['[Loia, Vincenzo; Vitiello, Autilia', ' Univ Salerno, Dept Comp Sci, I-84084 Fisciano, Italy.'] match ['Loia, Vincenzo; Vitiello, Autilia']
#
#  split_name_tokens :  ['Loia, Vincenzo', ' Vitiello, Autilia']
# institution UnivSalerno
#
#  Comes in try block
# each_author Loia, Vincenzo ins U
#
#  comes in catch block
# inst_dict {'Loia, Vincenzo': 'U'}
#
#  c1_str : [Zadeh, Parisa D. Hossein; Reformat, Marek Z.] Univ Alberta, Dept Elect & Comp Engn, Edmonton, AB, Canada.
#
#  match  found :  ['Zadeh, Parisa D. Hossein; Reformat, Marek Z.']
# authors_inst_list: ['[Zadeh, Parisa D. Hossein; Reformat, Marek Z.', ' Univ Alberta, Dept Elect & Comp Engn, Edmonton, AB, Canada.'] match ['Zadeh, Parisa D. Hossein; Reformat, Marek Z.']
#
#  split_name_tokens :  ['Zadeh, Parisa D. Hossein', ' Reformat, Marek Z.']
# institution UnivAlberta
#
#  Comes in try block
# each_author Zadeh, Parisa D. Hossein ins U
#
#  comes in catch block
# inst_dict {'Zadeh, Parisa D. Hossein': 'U'}
#
#  c1_str : [Keator, D. B.; Van Erp, T. G. M.] Univ Calif Irvine, Dept Psychiat & Human Behav, Irvine, CA 92617 USA.
#
#  match  found :  ['Keator, D. B.; Van Erp, T. G. M.']
# authors_inst_list: ['[Keator, D. B.; Van Erp, T. G. M.', ' Univ Calif Irvine, Dept Psychiat & Human Behav, Irvine, CA 92617 USA.'] match ['Keator, D. B.; Van Erp, T. G. M.']
#
#  split_name_tokens :  ['Keator, D. B.', ' Van Erp, T. G. M.']
# institution UnivCalifIrvine
#
#  c1_str : [Keator, D. B.] Univ Calif Irvine, Dept Comp Sci, Irvine, CA 92617 USA.
#
#  match  found :  ['Keator, D. B.']
# authors_inst_list: ['[Keator, D. B.', ' Univ Calif Irvine, Dept Comp Sci, Irvine, CA 92617 USA.'] match ['Keator, D. B.']
#
#  split_name_tokens :  ['Keator, D. B.']
# institution UnivCalifIrvine
#
#  c1_str : [Helmer, K.] Massachusetts Gen Hosp, Athinoula A Martinos Ctr Biomed Imaging, Boston, MA USA.
#
#  match  found :  ['Helmer, K.']
# authors_inst_list: ['[Helmer, K.', ' Massachusetts Gen Hosp, Athinoula A Martinos Ctr Biomed Imaging, Boston, MA USA.'] match ['Helmer, K.']
#
#  split_name_tokens :  ['Helmer, K.']
# institution MassachusettsGenHosp
#
#  c1_str : [Helmer, K.] Harvard Univ, Sch Med, Dept Radiol, Boston, MA 02115 USA.
#
#  match  found :  ['Helmer, K.']
# authors_inst_list: ['[Helmer, K.', ' Harvard Univ, Sch Med, Dept Radiol, Boston, MA 02115 USA.'] match ['Helmer, K.']
#
#  split_name_tokens :  ['Helmer, K.']
# institution HarvardUniv
#
#  c1_str : [Steffener, J.] Columbia Univ, Taub Inst Res Alzheimers Dis & Aging Brain, Dept Neurol, New York, NY 10027 USA.
#
#  match  found :  ['Steffener, J.']
# authors_inst_list: ['[Steffener, J.', ' Columbia Univ, Taub Inst Res Alzheimers Dis & Aging Brain, Dept Neurol, New York, NY 10027 USA.'] match ['Steffener, J.']
#
#  split_name_tokens :  ['Steffener, J.']
# institution ColumbiaUniv
#
#  c1_str : [Turner, J. A.] Mind Res Network, Albuquerque, NM USA.
#
#  match  found :  ['Turner, J. A.']
# authors_inst_list: ['[Turner, J. A.', ' Mind Res Network, Albuquerque, NM USA.'] match ['Turner, J. A.']
#
#  split_name_tokens :  ['Turner, J. A.']
# institution MindResNetwork
#
#  c1_str : [Gadde, S.] Duke Univ, Brain Imaging & Anal Ctr, Durham, NC 27706 USA.
#
#  match  found :  ['Gadde, S.']
# authors_inst_list: ['[Gadde, S.', ' Duke Univ, Brain Imaging & Anal Ctr, Durham, NC 27706 USA.'] match ['Gadde, S.']
#
#  split_name_tokens :  ['Gadde, S.']
# institution DukeUniv
#
#  c1_str : [Ashish, N.] Univ Calif Irvine, Calif Inst Telecommun & Informat Technol CalIT2, Irvine, CA 92617 USA.
#
#  match  found :  ['Ashish, N.']
# authors_inst_list: ['[Ashish, N.', ' Univ Calif Irvine, Calif Inst Telecommun & Informat Technol CalIT2, Irvine, CA 92617 USA.'] match ['Ashish, N.']
#
#  split_name_tokens :  ['Ashish, N.']
# institution UnivCalifIrvine
#
#  c1_str : [Burns, G. A.] Univ So Calif, Inst Informat Sci, Los Angeles, CA 90089 USA.
#
#  match  found :  ['Burns, G. A.']
# authors_inst_list: ['[Burns, G. A.', ' Univ So Calif, Inst Informat Sci, Los Angeles, CA 90089 USA.'] match ['Burns, G. A.']
#
#  split_name_tokens :  ['Burns, G. A.']
# institution UnivSoCalif
#
#  c1_str : [Nichols, B. N.] Univ Washington, Dept Biomed Informat & Med Educ, Seattle, WA 98195 USA.
#
#  match  found :  ['Nichols, B. N.']
# authors_inst_list: ['[Nichols, B. N.', ' Univ Washington, Dept Biomed Informat & Med Educ, Seattle, WA 98195 USA.'] match ['Nichols, B. N.']
#
#  split_name_tokens :  ['Nichols, B. N.']
# institution UnivWashington
#
#  c1_str : [Nichols, B. N.] Univ Washington, Dept Radiol, Integrated Brain Imaging Ctr, Seattle, WA 98195 USA.
#
#  match  found :  ['Nichols, B. N.']
# authors_inst_list: ['[Nichols, B. N.', ' Univ Washington, Dept Radiol, Integrated Brain Imaging Ctr, Seattle, WA 98195 USA.'] match ['Nichols, B. N.']
#
#  split_name_tokens :  ['Nichols, B. N.']
# institution UnivWashington
#
#  Comes in try block
# each_author Nichols, B. N. ins U
#
#  comes in catch block
# inst_dict {'Nichols, B. N.': 'U'}
#
#  c1_str : [Poelmans, Jonas; Dedene, Guido] Katholieke Univ Leuven, Fac Business & Econ, B-3000 Louvain, Belgium.
#
#  match  found :  ['Poelmans, Jonas; Dedene, Guido']
# authors_inst_list: ['[Poelmans, Jonas; Dedene, Guido', ' Katholieke Univ Leuven, Fac Business & Econ, B-3000 Louvain, Belgium.'] match ['Poelmans, Jonas; Dedene, Guido']
#
#  split_name_tokens :  ['Poelmans, Jonas', ' Dedene, Guido']
# institution KatholiekeUnivLeuven
#
#  c1_str : [Dedene, Guido] Univ Amsterdam, Sch Business, NL-1018 WB Amsterdam, Netherlands.
#
#  match  found :  ['Dedene, Guido']
# authors_inst_list: ['[Dedene, Guido', ' Univ Amsterdam, Sch Business, NL-1018 WB Amsterdam, Netherlands.'] match ['Dedene, Guido']
#
#  split_name_tokens :  ['Dedene, Guido']
# institution UnivAmsterdam
#
#  c1_str : [Poelmans, Jonas; Ignatov, Dmitry I.; Kuznetsov, Sergei O.] Natl Res Univ, Higher Sch Econ, Moscow 109028, Russia.
#
#  match  found :  ['Poelmans, Jonas; Ignatov, Dmitry I.; Kuznetsov, Sergei O.']
# authors_inst_list: ['[Poelmans, Jonas; Ignatov, Dmitry I.; Kuznetsov, Sergei O.', ' Natl Res Univ, Higher Sch Econ, Moscow 109028, Russia.'] match ['Poelmans, Jonas; Ignatov, Dmitry I.; Kuznetsov, Sergei O.']
#
#  split_name_tokens :  ['Poelmans, Jonas', ' Ignatov, Dmitry I.', ' Kuznetsov, Sergei O.']
# institution NatlResUniv
#
#  Comes in try block
# each_author Poelmans, Jonas ins N
#
#  comes in catch block
# inst_dict {'Poelmans, Jonas': 'N'}
#
#  c1_str : [Sanchez, David; Batet, Montserrat; Viejo, Alexandre] Univ Rovira & Virgili, Dept Comp Sci & Math, E-43007 Tarragona, Spain.
#
#  match  found :  ['Sanchez, David; Batet, Montserrat; Viejo, Alexandre']
# authors_inst_list: ['[Sanchez, David; Batet, Montserrat; Viejo, Alexandre', ' Univ Rovira & Virgili, Dept Comp Sci & Math, E-43007 Tarragona, Spain.'] match ['Sanchez, David; Batet, Montserrat; Viejo, Alexandre']
#
#  split_name_tokens :  ['Sanchez, David', ' Batet, Montserrat', ' Viejo, Alexandre']
# institution UnivRovira&Virgili
#
#  Comes in try block
# each_author Sanchez, David ins U
#
#  comes in catch block
# inst_dict {'Sanchez, David': 'U'}
#
#  c1_str : [Deng, Jintian; Choi, Byron; Xu, Jianliang; Hu, Haibo] Hong Kong Baptist Univ, Dept Comp Sci, Hong Kong, Hong Kong, Peoples R China.
#
#  match  found :  ['Deng, Jintian; Choi, Byron; Xu, Jianliang; Hu, Haibo']
# authors_inst_list: ['[Deng, Jintian; Choi, Byron; Xu, Jianliang; Hu, Haibo', ' Hong Kong Baptist Univ, Dept Comp Sci, Hong Kong, Hong Kong, Peoples R China.'] match ['Deng, Jintian; Choi, Byron; Xu, Jianliang; Hu, Haibo']
#
#  split_name_tokens :  ['Deng, Jintian', ' Choi, Byron', ' Xu, Jianliang', ' Hu, Haibo']
# institution HongKongBaptistUniv
#
#  c1_str : [Bhowmick, Sourav S.] Nanyang Technol Univ, Sch Comp Engn, Nanyang, Peoples R China.
#
#  match  found :  ['Bhowmick, Sourav S.']
# authors_inst_list: ['[Bhowmick, Sourav S.', ' Nanyang Technol Univ, Sch Comp Engn, Nanyang, Peoples R China.'] match ['Bhowmick, Sourav S.']
#
#  split_name_tokens :  ['Bhowmick, Sourav S.']
# institution NanyangTechnolUniv
#
#  Comes in try block
# each_author Bhowmick, Sourav S. ins N
#
#  comes in catch block
# inst_dict {'Bhowmick, Sourav S.': 'N'}
#
#  c1_str : [Tahir, Abbas; Tosi, Davide; Morasca, Sandro] Univ Insubria, Dept Theoret & Appl Sci, I-21100 Como, Italy.
#
#  match  found :  ['Tahir, Abbas; Tosi, Davide; Morasca, Sandro']
# authors_inst_list: ['[Tahir, Abbas; Tosi, Davide; Morasca, Sandro', ' Univ Insubria, Dept Theoret & Appl Sci, I-21100 Como, Italy.'] match ['Tahir, Abbas; Tosi, Davide; Morasca, Sandro']
#
#  split_name_tokens :  ['Tahir, Abbas', ' Tosi, Davide', ' Morasca, Sandro']
# institution UnivInsubria
#
#  c1_str : [Tahir, Abbas] Siemens AG, Corp Technol, D-81739 Munich, Germany.
#
#  match  found :  ['Tahir, Abbas']
# authors_inst_list: ['[Tahir, Abbas', ' Siemens AG, Corp Technol, D-81739 Munich, Germany.'] match ['Tahir, Abbas']
#
#  split_name_tokens :  ['Tahir, Abbas']
# institution SiemensAG
#
#  Comes in try block
# each_author Tahir, Abbas ins S
#
#  comes in catch block
# inst_dict {'Tahir, Abbas': 'S'}
#
#  c1_str : [Zhong, Yanru; Qin, Yuchu; Gao, Wenxiang; Du, Yulu] Guilin Univ Elect Technol, Sch Comp Sci & Engn, Guilin 541004, Peoples R China.
#
#  match  found :  ['Zhong, Yanru; Qin, Yuchu; Gao, Wenxiang; Du, Yulu']
# authors_inst_list: ['[Zhong, Yanru; Qin, Yuchu; Gao, Wenxiang; Du, Yulu', ' Guilin Univ Elect Technol, Sch Comp Sci & Engn, Guilin 541004, Peoples R China.'] match ['Zhong, Yanru; Qin, Yuchu; Gao, Wenxiang; Du, Yulu']
#
#  split_name_tokens :  ['Zhong, Yanru', ' Qin, Yuchu', ' Gao, Wenxiang', ' Du, Yulu']
# institution GuilinUnivElectTechnol
#
#  c1_str : [Huang, Meifa] Guilin Univ Elect Technol, Sch Mech & Elect Engn, Guilin 541004, Peoples R China.
#
#  match  found :  ['Huang, Meifa']
# authors_inst_list: ['[Huang, Meifa', ' Guilin Univ Elect Technol, Sch Mech & Elect Engn, Guilin 541004, Peoples R China.'] match ['Huang, Meifa']
#
#  split_name_tokens :  ['Huang, Meifa']
# institution GuilinUnivElectTechnol
#
#  c1_str : [Lu, Wenlong] Huazhong Univ Sci & Technol, Sch Mech Sci & Engn, State Key Lab Digital Mfg Equipment & Technol, Wuhan 430074, Peoples R China.
#
#  match  found :  ['Lu, Wenlong']
# authors_inst_list: ['[Lu, Wenlong', ' Huazhong Univ Sci & Technol, Sch Mech Sci & Engn, State Key Lab Digital Mfg Equipment & Technol, Wuhan 430074, Peoples R China.'] match ['Lu, Wenlong']
#
#  split_name_tokens :  ['Lu, Wenlong']
# institution HuazhongUnivSci&Technol
#
#  Comes in try block
# each_author Lu, Wenlong ins H
#
#  comes in catch block
# inst_dict {'Lu, Wenlong': 'H'}
#
#  c1_str : [Han, Lixin] Hohai Univ, Coll Comp & Informat, Nanjing, Jiangsu, Peoples R China.
#
#  match  found :  ['Han, Lixin']
# authors_inst_list: ['[Han, Lixin', ' Hohai Univ, Coll Comp & Informat, Nanjing, Jiangsu, Peoples R China.'] match ['Han, Lixin']
#
#  split_name_tokens :  ['Han, Lixin']
# institution HohaiUniv
#
#  c1_str : [Han, Lixin; Chen, Guihai] Nanjing Univ, State Key Lab Novel Software Technol, Nanjing, Jiangsu, Peoples R China.
#
#  match  found :  ['Han, Lixin; Chen, Guihai']
# authors_inst_list: ['[Han, Lixin; Chen, Guihai', ' Nanjing Univ, State Key Lab Novel Software Technol, Nanjing, Jiangsu, Peoples R China.'] match ['Han, Lixin; Chen, Guihai']
#
#  split_name_tokens :  ['Han, Lixin', ' Chen, Guihai']
# institution NanjingUniv
#
#  c1_str : [Han, Lixin] Nanjing Univ, Dept Math, Nanjing, Jiangsu, Peoples R China.
#
#  match  found :  ['Han, Lixin']
# authors_inst_list: ['[Han, Lixin', ' Nanjing Univ, Dept Math, Nanjing, Jiangsu, Peoples R China.'] match ['Han, Lixin']
#
#  split_name_tokens :  ['Han, Lixin']
# institution NanjingUniv
#
#  c1_str : [Li, Ming] E China Normal Univ, Sch Informat Sci & Technol, Shanghai, Peoples R China.
#
#  match  found :  ['Li, Ming']
# authors_inst_list: ['[Li, Ming', ' E China Normal Univ, Sch Informat Sci & Technol, Shanghai, Peoples R China.'] match ['Li, Ming']
#
#  split_name_tokens :  ['Li, Ming']
# institution EChinaNormalUniv
#
#  Comes in try block
# each_author Li, Ming ins E
#
#  comes in catch block
# inst_dict {'Li, Ming': 'E'}
#
#  c1_str : [Rios-Alvarado, Ana B.; Lopez-Arevalo, Ivan; Sosa-Sosa, Victor J.] TECNOTAM, Cinvestav Tamaulipas, Victoria 87130, Mexico.
#
#  match  found :  ['Rios-Alvarado, Ana B.; Lopez-Arevalo, Ivan; Sosa-Sosa, Victor J.']
# authors_inst_list: ['[Rios-Alvarado, Ana B.; Lopez-Arevalo, Ivan; Sosa-Sosa, Victor J.', ' TECNOTAM, Cinvestav Tamaulipas, Victoria 87130, Mexico.'] match ['Rios-Alvarado, Ana B.; Lopez-Arevalo, Ivan; Sosa-Sosa, Victor J.']
#
#  split_name_tokens :  ['Rios-Alvarado, Ana B.', ' Lopez-Arevalo, Ivan', ' Sosa-Sosa, Victor J.']
# institution TECNOTAM
#
#  Comes in try block
# each_author Rios-Alvarado, Ana B. ins T
#
#  comes in catch block
# inst_dict {'Rios-Alvarado, Ana B.': 'T'}
#
#  c1_str : [Duan, Jiangjiao] Fudan Univ, Sch Econ, Shanghai 200433, Peoples R China.
#
#  match  found :  ['Duan, Jiangjiao']
# authors_inst_list: ['[Duan, Jiangjiao', ' Fudan Univ, Sch Econ, Shanghai 200433, Peoples R China.'] match ['Duan, Jiangjiao']
#
#  split_name_tokens :  ['Duan, Jiangjiao']
# institution FudanUniv
#
#  c1_str : [Zeng, Jianping] Fudan Univ, Sch Comp Sci, Shanghai 200433, Peoples R China.
#
#  match  found :  ['Zeng, Jianping']
# authors_inst_list: ['[Zeng, Jianping', ' Fudan Univ, Sch Comp Sci, Shanghai 200433, Peoples R China.'] match ['Zeng, Jianping']
#
#  split_name_tokens :  ['Zeng, Jianping']
# institution FudanUniv
#
#  Comes in try block
# each_author Zeng, Jianping ins F
#
#  comes in catch block
# inst_dict {'Zeng, Jianping': 'F'}
#
#  c1_str : [Abanda, F. H.; Tah, J. H. M.; Keivani, R.] Oxford Brookes Univ, Oxford Inst Sustainable Dev, Dept Real Estate & Construct, Fac Technol Design & Environm, Oxford OX3 0BP, England.
#
#  match  found :  ['Abanda, F. H.; Tah, J. H. M.; Keivani, R.']
# authors_inst_list: ['[Abanda, F. H.; Tah, J. H. M.; Keivani, R.', ' Oxford Brookes Univ, Oxford Inst Sustainable Dev, Dept Real Estate & Construct, Fac Technol Design & Environm, Oxford OX3 0BP, England.'] match ['Abanda, F. H.; Tah, J. H. M.; Keivani, R.']
#
#  split_name_tokens :  ['Abanda, F. H.', ' Tah, J. H. M.', ' Keivani, R.']
# institution OxfordBrookesUniv
#
#  Comes in try block
# each_author Abanda, F. H. ins O
#
#  comes in catch block
# inst_dict {'Abanda, F. H.': 'O'}
#
#  c1_str : [Dutta, Ritaban] CSIRO, Intelligent Sensing & Syst Lab, Hobart, Tas 7001, Australia.
#
#  match  found :  ['Dutta, Ritaban']
# authors_inst_list: ['[Dutta, Ritaban', ' CSIRO, Intelligent Sensing & Syst Lab, Hobart, Tas 7001, Australia.'] match ['Dutta, Ritaban']
#
#  split_name_tokens :  ['Dutta, Ritaban']
# institution CSIRO
#
#  c1_str : [Morshed, Ahsan] UNO, FAO, Rome, Italy.
#
#  match  found :  ['Morshed, Ahsan']
# authors_inst_list: ['[Morshed, Ahsan', ' UNO, FAO, Rome, Italy.'] match ['Morshed, Ahsan']
#
#  split_name_tokens :  ['Morshed, Ahsan']
# institution UNO
#
#  Comes in try block
# each_author Morshed, Ahsan ins U
#
#  comes in catch block
# inst_dict {'Morshed, Ahsan': 'U'}
#
#  c1_str : [Karla, Pramukh R.] Texas A&M Univ, Dept Comp Sci & Informat Syst, Commerce, TX USA.
#
#  match  found :  ['Karla, Pramukh R.']
# authors_inst_list: ['[Karla, Pramukh R.', ' Texas A&M Univ, Dept Comp Sci & Informat Syst, Commerce, TX USA.'] match ['Karla, Pramukh R.']
#
#  split_name_tokens :  ['Karla, Pramukh R.']
# institution TexasA&MUniv
#
#  c1_str : [Gurupur, Varadraj P.] Louisiana Inst Technol, Dept Hlth Informat & Informat Management, Ruston, LA USA.
#
#  match  found :  ['Gurupur, Varadraj P.']
# authors_inst_list: ['[Gurupur, Varadraj P.', ' Louisiana Inst Technol, Dept Hlth Informat & Informat Management, Ruston, LA USA.'] match ['Gurupur, Varadraj P.']
#
#  split_name_tokens :  ['Gurupur, Varadraj P.']
# institution LouisianaInstTechnol
#
#  Comes in try block
# each_author Gurupur, Varadraj P. ins L
#
#  comes in catch block
# inst_dict {'Gurupur, Varadraj P.': 'L'}
#
#  c1_str : [Cheng, Sheng-Tzong; Chou, Chih-Lun; Horng, Gwo-Jiun] Natl Cheng Kung Univ, Dept Comp Sci & Informat Engn, Tainan 70101, Taiwan.
#
#  match  found :  ['Cheng, Sheng-Tzong; Chou, Chih-Lun; Horng, Gwo-Jiun']
# authors_inst_list: ['[Cheng, Sheng-Tzong; Chou, Chih-Lun; Horng, Gwo-Jiun', ' Natl Cheng Kung Univ, Dept Comp Sci & Informat Engn, Tainan 70101, Taiwan.'] match ['Cheng, Sheng-Tzong; Chou, Chih-Lun; Horng, Gwo-Jiun']
#
#  split_name_tokens :  ['Cheng, Sheng-Tzong', ' Chou, Chih-Lun', ' Horng, Gwo-Jiun']
# institution NatlChengKungUniv
#
#  Comes in try block
# each_author Cheng, Sheng-Tzong ins N
#
#  comes in catch block
# inst_dict {'Cheng, Sheng-Tzong': 'N'}
#
#  c1_str : [Sinaci, A. Anil] Middle E Tech Univ, Dept Comp Engn, TR-06800 Ankara, Turkey.
#
#  match  found :  ['Sinaci, A. Anil']
# authors_inst_list: ['[Sinaci, A. Anil', ' Middle E Tech Univ, Dept Comp Engn, TR-06800 Ankara, Turkey.'] match ['Sinaci, A. Anil']
#
#  split_name_tokens :  ['Sinaci, A. Anil']
# institution MiddleETechUniv
#
#  c1_str : [Sinaci, A. Anil; Erturkmen, Gokce B. Laleci] SRDC Software Res & Dev & Consultancy Ltd, TR-06800 Ankara, Turkey.
#
#  match  found :  ['Sinaci, A. Anil; Erturkmen, Gokce B. Laleci']
# authors_inst_list: ['[Sinaci, A. Anil; Erturkmen, Gokce B. Laleci', ' SRDC Software Res & Dev & Consultancy Ltd, TR-06800 Ankara, Turkey.'] match ['Sinaci, A. Anil; Erturkmen, Gokce B. Laleci']
#
#  split_name_tokens :  ['Sinaci, A. Anil', ' Erturkmen, Gokce B. Laleci']
# institution SRDCSoftwareRes&Dev&ConsultancyLtd
#
#  Comes in try block
# each_author Sinaci, A. Anil ins S
#
#  comes in catch block
# inst_dict {'Sinaci, A. Anil': 'S'}
#
#  c1_str : [Tao, Cui] Univ Texas Hlth Sci Ctr Houston, Sch Biomed Informat, Houston, TX 77030 USA.
#
#  match  found :  ['Tao, Cui']
# authors_inst_list: ['[Tao, Cui', ' Univ Texas Hlth Sci Ctr Houston, Sch Biomed Informat, Houston, TX 77030 USA.'] match ['Tao, Cui']
#
#  split_name_tokens :  ['Tao, Cui']
# institution UnivTexasHlthSciCtrHouston
#
#  c1_str : [Tao, Cui; Song, Dezhao; Sharma, Deepak; Chute, Christopher G.] Mayo Clin, Div Biomed Stat & Informat, Rochester, MN 55905 USA.
#
#  match  found :  ['Tao, Cui; Song, Dezhao; Sharma, Deepak; Chute, Christopher G.']
# authors_inst_list: ['[Tao, Cui; Song, Dezhao; Sharma, Deepak; Chute, Christopher G.', ' Mayo Clin, Div Biomed Stat & Informat, Rochester, MN 55905 USA.'] match ['Tao, Cui; Song, Dezhao; Sharma, Deepak; Chute, Christopher G.']
#
#  split_name_tokens :  ['Tao, Cui', ' Song, Dezhao', ' Sharma, Deepak', ' Chute, Christopher G.']
# institution MayoClin
#
#  c1_str : [Song, Dezhao] Lehigh Univ, Dept Comp Sci & Engn, Bethlehem, PA 18017 USA.
#
#  match  found :  ['Song, Dezhao']
# authors_inst_list: ['[Song, Dezhao', ' Lehigh Univ, Dept Comp Sci & Engn, Bethlehem, PA 18017 USA.'] match ['Song, Dezhao']
#
#  split_name_tokens :  ['Song, Dezhao']
# institution LehighUniv
#
#  Comes in try block
# each_author Song, Dezhao ins L
#
#  comes in catch block
# inst_dict {'Song, Dezhao': 'L'}
#
#  c1_str : [Ballatore, Andrea; Bertolotto, Michela] Univ Coll Dublin, Sch Comp Sci & Informat, Dublin 4, Ireland.
#
#  match  found :  ['Ballatore, Andrea; Bertolotto, Michela']
# authors_inst_list: ['[Ballatore, Andrea; Bertolotto, Michela', ' Univ Coll Dublin, Sch Comp Sci & Informat, Dublin 4, Ireland.'] match ['Ballatore, Andrea; Bertolotto, Michela']
#
#  split_name_tokens :  ['Ballatore, Andrea', ' Bertolotto, Michela']
# institution UnivCollDublin
#
#  c1_str : [Wilson, David C.] Univ N Carolina, Dept Software & Informat Syst, Charlotte, NC 28223 USA.
#
#  match  found :  ['Wilson, David C.']
# authors_inst_list: ['[Wilson, David C.', ' Univ N Carolina, Dept Software & Informat Syst, Charlotte, NC 28223 USA.'] match ['Wilson, David C.']
#
#  split_name_tokens :  ['Wilson, David C.']
# institution UnivNCarolina
#
#  Comes in try block
# each_author Wilson, David C. ins U
#
#  comes in catch block
# inst_dict {'Wilson, David C.': 'U'}
#
#  c1_str : [Goasdoue, Francois; Leblay, Julien; Manolescu, Ioana; Zampetakis, Stamatis] Inria Saclay, Orsay, France.
#
#  match  found :  ['Goasdoue, Francois; Leblay, Julien; Manolescu, Ioana; Zampetakis, Stamatis']
# authors_inst_list: ['[Goasdoue, Francois; Leblay, Julien; Manolescu, Ioana; Zampetakis, Stamatis', ' Inria Saclay, Orsay, France.'] match ['Goasdoue, Francois; Leblay, Julien; Manolescu, Ioana; Zampetakis, Stamatis']
#
#  split_name_tokens :  ['Goasdoue, Francois', ' Leblay, Julien', ' Manolescu, Ioana', ' Zampetakis, Stamatis']
# institution InriaSaclay
#
#  c1_str : [Goasdoue, Francois; Leblay, Julien; Manolescu, Ioana; Zampetakis, Stamatis] Univ Paris 11, Orsay, France.
#
#  match  found :  ['Goasdoue, Francois; Leblay, Julien; Manolescu, Ioana; Zampetakis, Stamatis']
# authors_inst_list: ['[Goasdoue, Francois; Leblay, Julien; Manolescu, Ioana; Zampetakis, Stamatis', ' Univ Paris 11, Orsay, France.'] match ['Goasdoue, Francois; Leblay, Julien; Manolescu, Ioana; Zampetakis, Stamatis']
#
#  split_name_tokens :  ['Goasdoue, Francois', ' Leblay, Julien', ' Manolescu, Ioana', ' Zampetakis, Stamatis']
# institution UnivParis11
#
#  c1_str : [Karanasos, Konstantinos] Almaden Res Ctr, San Jose, CA USA.
#
#  match  found :  ['Karanasos, Konstantinos']
# authors_inst_list: ['[Karanasos, Konstantinos', ' Almaden Res Ctr, San Jose, CA USA.'] match ['Karanasos, Konstantinos']
#
#  split_name_tokens :  ['Karanasos, Konstantinos']
# institution AlmadenResCtr
#
#  c1_str : [Katsis, Yannis] Univ Calif San Diego, San Diego, CA USA.
#
#  match  found :  ['Katsis, Yannis']
# authors_inst_list: ['[Katsis, Yannis', ' Univ Calif San Diego, San Diego, CA USA.'] match ['Katsis, Yannis']
#
#  split_name_tokens :  ['Katsis, Yannis']
# institution UnivCalifSanDiego
#
#  Comes in try block
# each_author Katsis, Yannis ins U
#
#  comes in catch block
# inst_dict {'Katsis, Yannis': 'U'}
#
#  c1_str : [Furche, Tim; Gottlob, Georg; Grasso, Giovanni; Guo, Xiaonan; Orsi, Giorgio; Schallhart, Christian] Univ Oxford, Dept Comp Sci, Oxford OX1 3QD, England.
#
#  match  found :  ['Furche, Tim; Gottlob, Georg; Grasso, Giovanni; Guo, Xiaonan; Orsi, Giorgio; Schallhart, Christian']
# authors_inst_list: ['[Furche, Tim; Gottlob, Georg; Grasso, Giovanni; Guo, Xiaonan; Orsi, Giorgio; Schallhart, Christian', ' Univ Oxford, Dept Comp Sci, Oxford OX1 3QD, England.'] match ['Furche, Tim; Gottlob, Georg; Grasso, Giovanni; Guo, Xiaonan; Orsi, Giorgio; Schallhart, Christian']
#
#  split_name_tokens :  ['Furche, Tim', ' Gottlob, Georg', ' Grasso, Giovanni', ' Guo, Xiaonan', ' Orsi, Giorgio', ' Schallhart, Christian']
# institution UnivOxford
#
#  Comes in try block
# each_author Furche, Tim ins U
#
#  comes in catch block
# inst_dict {'Furche, Tim': 'U'}
#
#  c1_str : [Bozzon, Alessandro; Brambilla, Marco; Ceri, Stefano; Mazza, Davide] Politecn Milan, Dipartimento Elettron Informaz & Bioingn, I-20133 Milan, Italy.
#
#  match  found :  ['Bozzon, Alessandro; Brambilla, Marco; Ceri, Stefano; Mazza, Davide']
# authors_inst_list: ['[Bozzon, Alessandro; Brambilla, Marco; Ceri, Stefano; Mazza, Davide', ' Politecn Milan, Dipartimento Elettron Informaz & Bioingn, I-20133 Milan, Italy.'] match ['Bozzon, Alessandro; Brambilla, Marco; Ceri, Stefano; Mazza, Davide']
#
#  split_name_tokens :  ['Bozzon, Alessandro', ' Brambilla, Marco', ' Ceri, Stefano', ' Mazza, Davide']
# institution PolitecnMilan
#
#  Comes in try block
# each_author Bozzon, Alessandro ins P
#
#  comes in catch block
# inst_dict {'Bozzon, Alessandro': 'P'}
#
#  c1_str : [Gracy, Karen F.; Zeng, Marcia Lei; Skirvin, Laurence] Kent State Univ, Sch Lib & Informat Sci, Kent, OH 44242 USA.
#
#  match  found :  ['Gracy, Karen F.; Zeng, Marcia Lei; Skirvin, Laurence']
# authors_inst_list: ['[Gracy, Karen F.; Zeng, Marcia Lei; Skirvin, Laurence', ' Kent State Univ, Sch Lib & Informat Sci, Kent, OH 44242 USA.'] match ['Gracy, Karen F.; Zeng, Marcia Lei; Skirvin, Laurence']
#
#  split_name_tokens :  ['Gracy, Karen F.', ' Zeng, Marcia Lei', ' Skirvin, Laurence']
# institution KentStateUniv
#
#  Comes in try block
# each_author Gracy, Karen F. ins K
#
#  comes in catch block
# inst_dict {'Gracy, Karen F.': 'K'}
#
#  c1_str : Univ Antwerp, IBW, B-2000 Antwerp, Belgium.
#
#  match  not found []
#
#  institution in else part : Univ Antwerp
#
#  Comes in try block
#
#  c1_str : [Cuxac, Pascal; Bonvallot, Valerie] INIST CNRS, Vandoeuvre Les Nancy, France.
#
#  match  found :  ['Cuxac, Pascal; Bonvallot, Valerie']
# authors_inst_list: ['[Cuxac, Pascal; Bonvallot, Valerie', ' INIST CNRS, Vandoeuvre Les Nancy, France.'] match ['Cuxac, Pascal; Bonvallot, Valerie']
#
#  split_name_tokens :  ['Cuxac, Pascal', ' Bonvallot, Valerie']
# institution INISTCNRS
#
#  c1_str : [Lamirel, Jean-Charles] LORIA Synalp, Vandoeuvre Les Nancy, France.
#
#  match  found :  ['Lamirel, Jean-Charles']
# authors_inst_list: ['[Lamirel, Jean-Charles', ' LORIA Synalp, Vandoeuvre Les Nancy, France.'] match ['Lamirel, Jean-Charles']
#
#  split_name_tokens :  ['Lamirel, Jean-Charles']
# institution LORIASynalp
#
#  Comes in try block
# each_author Lamirel, Jean-Charles ins L
#
#  comes in catch block
# inst_dict {'Lamirel, Jean-Charles': 'L'}
#
#  c1_str : [Cases, M.; Furlong, L. I.; Lopez-Bigas, N.; Mayer, M. A.; Sanz, F.] Univ Pompeu Fabra, DCEXS, IMIM, Res Programme Biomed Informat GRIB, Barcelona, Spain.
#
#  match  found :  ['Cases, M.; Furlong, L. I.; Lopez-Bigas, N.; Mayer, M. A.; Sanz, F.']
# authors_inst_list: ['[Cases, M.; Furlong, L. I.; Lopez-Bigas, N.; Mayer, M. A.; Sanz, F.', ' Univ Pompeu Fabra, DCEXS, IMIM, Res Programme Biomed Informat GRIB, Barcelona, Spain.'] match ['Cases, M.; Furlong, L. I.; Lopez-Bigas, N.; Mayer, M. A.; Sanz, F.']
#
#  split_name_tokens :  ['Cases, M.', ' Furlong, L. I.', ' Lopez-Bigas, N.', ' Mayer, M. A.', ' Sanz, F.']
# institution UnivPompeuFabra
#
#  c1_str : [Albanell, J.] Univ Pompeu Fabra, DCEXS, IMIM, Hosp del Mar,Serv Oncol, Barcelona, Spain.
#
#  match  found :  ['Albanell, J.']
# authors_inst_list: ['[Albanell, J.', ' Univ Pompeu Fabra, DCEXS, IMIM, Hosp del Mar,Serv Oncol, Barcelona, Spain.'] match ['Albanell, J.']
#
#  split_name_tokens :  ['Albanell, J.']
# institution UnivPompeuFabra
#
#  c1_str : [Altman, R. B.] Stanford Univ, Dept Bioengn, Stanford, CA 94305 USA.
#
#  match  found :  ['Altman, R. B.']
# authors_inst_list: ['[Altman, R. B.', ' Stanford Univ, Dept Bioengn, Stanford, CA 94305 USA.'] match ['Altman, R. B.']
#
#  split_name_tokens :  ['Altman, R. B.']
# institution StanfordUniv
#
#  c1_str : [Altman, R. B.; Klein, T. E.] Stanford Univ, Dept Genet, Stanford, CA 94305 USA.
#
#  match  found :  ['Altman, R. B.; Klein, T. E.']
# authors_inst_list: ['[Altman, R. B.; Klein, T. E.', ' Stanford Univ, Dept Genet, Stanford, CA 94305 USA.'] match ['Altman, R. B.; Klein, T. E.']
#
#  split_name_tokens :  ['Altman, R. B.', ' Klein, T. E.']
# institution StanfordUniv
#
#  c1_str : [Altman, R. B.] Stanford Univ, Dept Med, Stanford, CA 94305 USA.
#
#  match  found :  ['Altman, R. B.']
# authors_inst_list: ['[Altman, R. B.', ' Stanford Univ, Dept Med, Stanford, CA 94305 USA.'] match ['Altman, R. B.']
#
#  split_name_tokens :  ['Altman, R. B.']
# institution StanfordUniv
#
#  c1_str : [Bellazzi, R.] Univ Pavia, Dipartimento Ingn Ind & Informaz, I-27100 Pavia, Italy.
#
#  match  found :  ['Bellazzi, R.']
# authors_inst_list: ['[Bellazzi, R.', ' Univ Pavia, Dipartimento Ingn Ind & Informaz, I-27100 Pavia, Italy.'] match ['Bellazzi, R.']
#
#  split_name_tokens :  ['Bellazzi, R.']
# institution UnivPavia
#
#  c1_str : [Boyer, S.] AstraZeneca, Safety Assessment, Molndal, Sweden.
#
#  match  found :  ['Boyer, S.']
# authors_inst_list: ['[Boyer, S.', ' AstraZeneca, Safety Assessment, Molndal, Sweden.'] match ['Boyer, S.']
#
#  split_name_tokens :  ['Boyer, S.']
# institution AstraZeneca
#
#  c1_str : [Brand, A.] Maastricht Univ, Inst Publ Hlth Genom, Maastricht, Netherlands.
#
#  match  found :  ['Brand, A.']
# authors_inst_list: ['[Brand, A.', ' Maastricht Univ, Inst Publ Hlth Genom, Maastricht, Netherlands.'] match ['Brand, A.']
#
#  split_name_tokens :  ['Brand, A.']
# institution MaastrichtUniv
#
#  c1_str : [Brookes, A. J.] Univ Leicester, Dept Genet, Leicester LE1 7RH, Leics, England.
#
#  match  found :  ['Brookes, A. J.']
# authors_inst_list: ['[Brookes, A. J.', ' Univ Leicester, Dept Genet, Leicester LE1 7RH, Leics, England.'] match ['Brookes, A. J.']
#
#  split_name_tokens :  ['Brookes, A. J.']
# institution UnivLeicester
#
#  c1_str : [Brunak, S.] Tech Univ Denmark, Univ Copenhagen, Ctr Biol Sequence Anal, Ctr Prot Res, DK-2800 Lyngby, Denmark.
#
#  match  found :  ['Brunak, S.']
# authors_inst_list: ['[Brunak, S.', ' Tech Univ Denmark, Univ Copenhagen, Ctr Biol Sequence Anal, Ctr Prot Res, DK-2800 Lyngby, Denmark.'] match ['Brunak, S.']
#
#  split_name_tokens :  ['Brunak, S.']
# institution TechUnivDenmark
#
#  c1_str : [Clark, T. W.] Massachusetts Gen Hosp, MassGen Inst Neurodegenerat Dis, Cambridge, MA USA.
#
#  match  found :  ['Clark, T. W.']
# authors_inst_list: ['[Clark, T. W.', ' Massachusetts Gen Hosp, MassGen Inst Neurodegenerat Dis, Cambridge, MA USA.'] match ['Clark, T. W.']
#
#  split_name_tokens :  ['Clark, T. W.']
# institution MassachusettsGenHosp
#
#  c1_str : [Gea, J.] Univ Pompeu Fabra, CIBERES, DCEXS, IMIM,Hosp del Mar,Serv Pneumol, Barcelona, Spain.
#
#  match  found :  ['Gea, J.']
# authors_inst_list: ['[Gea, J.', ' Univ Pompeu Fabra, CIBERES, DCEXS, IMIM,Hosp del Mar,Serv Pneumol, Barcelona, Spain.'] match ['Gea, J.']
#
#  split_name_tokens :  ['Gea, J.']
# institution UnivPompeuFabra
#
#  c1_str : [Ghazal, P.] Univ Edinburgh, Div Pathway Med, Edinburgh, Midlothian, Scotland.
#
#  match  found :  ['Ghazal, P.']
# authors_inst_list: ['[Ghazal, P.', ' Univ Edinburgh, Div Pathway Med, Edinburgh, Midlothian, Scotland.'] match ['Ghazal, P.']
#
#  split_name_tokens :  ['Ghazal, P.']
# institution UnivEdinburgh
#
#  c1_str : [Graf, N.] Univ Saarland, Dept Pediat Oncol & Hematol, Homburg, Germany.
#
#  match  found :  ['Graf, N.']
# authors_inst_list: ['[Graf, N.', ' Univ Saarland, Dept Pediat Oncol & Hematol, Homburg, Germany.'] match ['Graf, N.']
#
#  split_name_tokens :  ['Graf, N.']
# institution UnivSaarland
#
#  c1_str : [Guigo, R.] CRG, Barcelona, Spain.
#
#  match  found :  ['Guigo, R.']
# authors_inst_list: ['[Guigo, R.', ' CRG, Barcelona, Spain.'] match ['Guigo, R.']
#
#  split_name_tokens :  ['Guigo, R.']
# institution CRG
#
#  c1_str : [Guigo, R.; Valencia, A.; Sanz, F.] Spanish Inst Bioinformat INB, Madrid, Spain.
#
#  match  found :  ['Guigo, R.; Valencia, A.; Sanz, F.']
# authors_inst_list: ['[Guigo, R.; Valencia, A.; Sanz, F.', ' Spanish Inst Bioinformat INB, Madrid, Spain.'] match ['Guigo, R.; Valencia, A.; Sanz, F.']
#
#  split_name_tokens :  ['Guigo, R.', ' Valencia, A.', ' Sanz, F.']
# institution SpanishInstBioinformatINB
#
#  c1_str : [Lopez-Bigas, N.] ICREA, Barcelona, Spain.
#
#  match  found :  ['Lopez-Bigas, N.']
# authors_inst_list: ['[Lopez-Bigas, N.', ' ICREA, Barcelona, Spain.'] match ['Lopez-Bigas, N.']
#
#  split_name_tokens :  ['Lopez-Bigas, N.']
# institution ICREA
#
#  c1_str : [Maojo, V.] Univ Politecn Madrid, Biomed Informat Grp, Madrid, Spain.
#
#  match  found :  ['Maojo, V.']
# authors_inst_list: ['[Maojo, V.', ' Univ Politecn Madrid, Biomed Informat Grp, Madrid, Spain.'] match ['Maojo, V.']
#
#  split_name_tokens :  ['Maojo, V.']
# institution UnivPolitecnMadrid
#
#  c1_str : [Mons, B.] Leiden Univ, Dept Human Genet, Med Ctr, NL-2300 RA Leiden, Netherlands.
#
#  match  found :  ['Mons, B.']
# authors_inst_list: ['[Mons, B.', ' Leiden Univ, Dept Human Genet, Med Ctr, NL-2300 RA Leiden, Netherlands.'] match ['Mons, B.']
#
#  split_name_tokens :  ['Mons, B.']
# institution LeidenUniv
#
#  c1_str : [Mons, B.] Netherlands Bioinformat Ctr, Nijmegen, Netherlands.
#
#  match  found :  ['Mons, B.']
# authors_inst_list: ['[Mons, B.', ' Netherlands Bioinformat Ctr, Nijmegen, Netherlands.'] match ['Mons, B.']
#
#  split_name_tokens :  ['Mons, B.']
# institution NetherlandsBioinformatCtr
#
#  c1_str : [Musen, M.] Stanford Univ, Stanford Ctr Biomed Informat Res, Stanford, CA 94305 USA.
#
#  match  found :  ['Musen, M.']
# authors_inst_list: ['[Musen, M.', ' Stanford Univ, Stanford Ctr Biomed Informat Res, Stanford, CA 94305 USA.'] match ['Musen, M.']
#
#  split_name_tokens :  ['Musen, M.']
# institution StanfordUniv
#
#  c1_str : [Oliveira, J. L.] Univ Aveiro, DETI IEETA, P-3800 Aveiro, Portugal.
#
#  match  found :  ['Oliveira, J. L.']
# authors_inst_list: ['[Oliveira, J. L.', ' Univ Aveiro, DETI IEETA, P-3800 Aveiro, Portugal.'] match ['Oliveira, J. L.']
#
#  split_name_tokens :  ['Oliveira, J. L.']
# institution UnivAveiro
#
#  c1_str : [Ruch, P.] Univ Appl Sci, BITEM, Geneva, Switzerland.
#
#  match  found :  ['Ruch, P.']
# authors_inst_list: ['[Ruch, P.', ' Univ Appl Sci, BITEM, Geneva, Switzerland.'] match ['Ruch, P.']
#
#  split_name_tokens :  ['Ruch, P.']
# institution UnivApplSci
#
#  c1_str : [Shabo, A.] IBM Res Lab, Haifa, Israel.
#
#  match  found :  ['Shabo, A.']
# authors_inst_list: ['[Shabo, A.', ' IBM Res Lab, Haifa, Israel.'] match ['Shabo, A.']
#
#  split_name_tokens :  ['Shabo, A.']
# institution IBMResLab
#
#  c1_str : [Shortliffe, E. H.] Arizona State Univ, Phoenix, AZ USA.
#
#  match  found :  ['Shortliffe, E. H.']
# authors_inst_list: ['[Shortliffe, E. H.', ' Arizona State Univ, Phoenix, AZ USA.'] match ['Shortliffe, E. H.']
#
#  split_name_tokens :  ['Shortliffe, E. H.']
# institution ArizonaStateUniv
#
#  c1_str : [Shortliffe, E. H.] Columbia Univ, Dept Biomed Informat, New York, NY USA.
#
#  match  found :  ['Shortliffe, E. H.']
# authors_inst_list: ['[Shortliffe, E. H.', ' Columbia Univ, Dept Biomed Informat, New York, NY USA.'] match ['Shortliffe, E. H.']
#
#  split_name_tokens :  ['Shortliffe, E. H.']
# institution ColumbiaUniv
#
#  c1_str : [Valencia, A.] Spanish Natl Canc Res Ctr CNIO, Madrid, Spain.
#
#  match  found :  ['Valencia, A.']
# authors_inst_list: ['[Valencia, A.', ' Spanish Natl Canc Res Ctr CNIO, Madrid, Spain.'] match ['Valencia, A.']
#
#  split_name_tokens :  ['Valencia, A.']
# institution SpanishNatlCancResCtrCNIO
#
#  c1_str : [van der Lei, J.] Erasmus Univ, Dept Med Informat, Med Ctr, NL-3000 DR Rotterdam, Netherlands.
#
#  match  found :  ['van der Lei, J.']
# authors_inst_list: ['[van der Lei, J.', ' Erasmus Univ, Dept Med Informat, Med Ctr, NL-3000 DR Rotterdam, Netherlands.'] match ['van der Lei, J.']
#
#  split_name_tokens :  ['van der Lei, J.']
# institution ErasmusUniv
#
#  Comes in try block
# each_author van der Lei, J. ins E
#
#  comes in catch block
# inst_dict {'van der Lei, J.': 'E'}
#
#  c1_str : [Felber, Pascal; Kropf, Peter; Leonini, Lorenzo; Riviere, Etienne; Schiavoni, Valerio; Valerio, Jose] Univ Neuchatel, Inst Informat, CH-2009 Neuchatel, Switzerland.
#
#  match  found :  ['Felber, Pascal; Kropf, Peter; Leonini, Lorenzo; Riviere, Etienne; Schiavoni, Valerio; Valerio, Jose']
# authors_inst_list: ['[Felber, Pascal; Kropf, Peter; Leonini, Lorenzo; Riviere, Etienne; Schiavoni, Valerio; Valerio, Jose', ' Univ Neuchatel, Inst Informat, CH-2009 Neuchatel, Switzerland.'] match ['Felber, Pascal; Kropf, Peter; Leonini, Lorenzo; Riviere, Etienne; Schiavoni, Valerio; Valerio, Jose']
#
#  split_name_tokens :  ['Felber, Pascal', ' Kropf, Peter', ' Leonini, Lorenzo', ' Riviere, Etienne', ' Schiavoni, Valerio', ' Valerio, Jose']
# institution UnivNeuchatel
#
#  c1_str : [Luu, Toan; Rajman, Martin] Ecole Polytech Fed Lausanne, CH-1015 Lausanne, Switzerland.
#
#  match  found :  ['Luu, Toan; Rajman, Martin']
# authors_inst_list: ['[Luu, Toan; Rajman, Martin', ' Ecole Polytech Fed Lausanne, CH-1015 Lausanne, Switzerland.'] match ['Luu, Toan; Rajman, Martin']
#
#  split_name_tokens :  ['Luu, Toan', ' Rajman, Martin']
# institution EcolePolytechFedLausanne
#
#  Comes in try block
# each_author Luu, Toan ins E
#
#  comes in catch block
# inst_dict {'Luu, Toan': 'E'}
#
#  c1_str : [Vizcarra, Julio] CIC, Inst Politecn Nacl, Mexico City, DF, Mexico.
#
#  match  found :  ['Vizcarra, Julio']
# authors_inst_list: ['[Vizcarra, Julio', ' CIC, Inst Politecn Nacl, Mexico City, DF, Mexico.'] match ['Vizcarra, Julio']
#
#  split_name_tokens :  ['Vizcarra, Julio']
# institution CIC
#
#  c1_str : [Torres, Miguel; Quintero, Rolando; Moreno-Ibarra, Marco] IPN, Mexico City, DF, Mexico.
#
#  match  found :  ['Torres, Miguel; Quintero, Rolando; Moreno-Ibarra, Marco']
# authors_inst_list: ['[Torres, Miguel; Quintero, Rolando; Moreno-Ibarra, Marco', ' IPN, Mexico City, DF, Mexico.'] match ['Torres, Miguel; Quintero, Rolando; Moreno-Ibarra, Marco']
#
#  split_name_tokens :  ['Torres, Miguel', ' Quintero, Rolando', ' Moreno-Ibarra, Marco']
# institution IPN
#
#  Comes in try block
# each_author Torres, Miguel ins I
#
#  comes in catch block
# inst_dict {'Torres, Miguel': 'I'}
#
#  c1_str : [Mangione, Giuseppina Rita] Univ Salerno, CRMPA, Dipartimento Ingn Informaz Ingn Elettr & Matemat, Salerno, Italy.
#
#  match  found :  ['Mangione, Giuseppina Rita']
# authors_inst_list: ['[Mangione, Giuseppina Rita', ' Univ Salerno, CRMPA, Dipartimento Ingn Informaz Ingn Elettr & Matemat, Salerno, Italy.'] match ['Mangione, Giuseppina Rita']
#
#  split_name_tokens :  ['Mangione, Giuseppina Rita']
# institution UnivSalerno
#
#  c1_str : [Orciuoli, Francesco; Ritrovato, Pierluigi] Univ Salerno, MOMA SpA, Salerno, Italy.
#
#  match  found :  ['Orciuoli, Francesco; Ritrovato, Pierluigi']
# authors_inst_list: ['[Orciuoli, Francesco; Ritrovato, Pierluigi', ' Univ Salerno, MOMA SpA, Salerno, Italy.'] match ['Orciuoli, Francesco; Ritrovato, Pierluigi']
#
#  split_name_tokens :  ['Orciuoli, Francesco', ' Ritrovato, Pierluigi']
# institution UnivSalerno
#
#  c1_str : [Orciuoli, Francesco; Ritrovato, Pierluigi; Salerno, Saverio] Univ Salerno, Dipartimento Ingn Informaz Ingn Elettr & Matemat, Salerno, Italy.
#
#  match  found :  ['Orciuoli, Francesco; Ritrovato, Pierluigi; Salerno, Saverio']
# authors_inst_list: ['[Orciuoli, Francesco; Ritrovato, Pierluigi; Salerno, Saverio', ' Univ Salerno, Dipartimento Ingn Informaz Ingn Elettr & Matemat, Salerno, Italy.'] match ['Orciuoli, Francesco; Ritrovato, Pierluigi; Salerno, Saverio']
#
#  split_name_tokens :  ['Orciuoli, Francesco', ' Ritrovato, Pierluigi', ' Salerno, Saverio']
# institution UnivSalerno
#
#  Comes in try block
# each_author Orciuoli, Francesco ins U
#
#  comes in catch block
# inst_dict {'Orciuoli, Francesco': 'U'}
#
#  c1_str : [Zhang, Ziqi; Gentile, Anna Lisa; Ciravegna, Fabio] Univ Sheffield, Dept Comp Sci, Sheffield S1 4DP, S Yorkshire, England.
#
#  match  found :  ['Zhang, Ziqi; Gentile, Anna Lisa; Ciravegna, Fabio']
# authors_inst_list: ['[Zhang, Ziqi; Gentile, Anna Lisa; Ciravegna, Fabio', ' Univ Sheffield, Dept Comp Sci, Sheffield S1 4DP, S Yorkshire, England.'] match ['Zhang, Ziqi; Gentile, Anna Lisa; Ciravegna, Fabio']
#
#  split_name_tokens :  ['Zhang, Ziqi', ' Gentile, Anna Lisa', ' Ciravegna, Fabio']
# institution UnivSheffield
#
#  Comes in try block
# each_author Zhang, Ziqi ins U
#
#  comes in catch block
# inst_dict {'Zhang, Ziqi': 'U'}
#
#  c1_str : [Angrosh, M. A.; Cranefield, Stephen; Stanger, Nigel] Univ Otago, Dept Informat Sci, Dunedin, New Zealand.
#
#  match  found :  ['Angrosh, M. A.; Cranefield, Stephen; Stanger, Nigel']
# authors_inst_list: ['[Angrosh, M. A.; Cranefield, Stephen; Stanger, Nigel', ' Univ Otago, Dept Informat Sci, Dunedin, New Zealand.'] match ['Angrosh, M. A.; Cranefield, Stephen; Stanger, Nigel']
#
#  split_name_tokens :  ['Angrosh, M. A.', ' Cranefield, Stephen', ' Stanger, Nigel']
# institution UnivOtago
#
#  Comes in try block
# each_author Angrosh, M. A. ins U
#
#  comes in catch block
# inst_dict {'Angrosh, M. A.': 'U'}
#
#  c1_str : [Chen, Yuxin] ETH, Dept Comp Sci, CH-8092 Zurich, Switzerland.
#
#  match  found :  ['Chen, Yuxin']
# authors_inst_list: ['[Chen, Yuxin', ' ETH, Dept Comp Sci, CH-8092 Zurich, Switzerland.'] match ['Chen, Yuxin']
#
#  split_name_tokens :  ['Chen, Yuxin']
# institution ETH
#
#  c1_str : [Sampathkumar, Hariprasad; Luo, Bo] Univ Kansas, Dept Elect Engn & Comp Sci, Lawrence, KS 66045 USA.
#
#  match  found :  ['Sampathkumar, Hariprasad; Luo, Bo']
# authors_inst_list: ['[Sampathkumar, Hariprasad; Luo, Bo', ' Univ Kansas, Dept Elect Engn & Comp Sci, Lawrence, KS 66045 USA.'] match ['Sampathkumar, Hariprasad; Luo, Bo']
#
#  split_name_tokens :  ['Sampathkumar, Hariprasad', ' Luo, Bo']
# institution UnivKansas
#
#  c1_str : [Chen, Xue-wen] Wayne State Univ, Dept Comp Sci, Detroit, MI 48202 USA.
#
#  match  found :  ['Chen, Xue-wen']
# authors_inst_list: ['[Chen, Xue-wen', ' Wayne State Univ, Dept Comp Sci, Detroit, MI 48202 USA.'] match ['Chen, Xue-wen']
#
#  split_name_tokens :  ['Chen, Xue-wen']
# institution WayneStateUniv
#
#  Comes in try block
# each_author Chen, Xue-wen ins W
#
#  comes in catch block
# inst_dict {'Chen, Xue-wen': 'W'}
#
#  c1_str : [Laznik, Jurij] Banka Celje Dd, Celje 3000, Slovenia.
#
#  match  found :  ['Laznik, Jurij']
# authors_inst_list: ['[Laznik, Jurij', ' Banka Celje Dd, Celje 3000, Slovenia.'] match ['Laznik, Jurij']
#
#  split_name_tokens :  ['Laznik, Jurij']
# institution BankaCeljeDd
#
#  c1_str : [Laznik, Jurij] Univ Maribor, Fac Comp & Informat Sci, SI-2000 Maribor, Slovenia.
#
#  match  found :  ['Laznik, Jurij']
# authors_inst_list: ['[Laznik, Jurij', ' Univ Maribor, Fac Comp & Informat Sci, SI-2000 Maribor, Slovenia.'] match ['Laznik, Jurij']
#
#  split_name_tokens :  ['Laznik, Jurij']
# institution UnivMaribor
#
#  c1_str : [Juric, Matjaz B.] Univ Ljubljana, Fac Comp & Informat Sci, SI-1000 Ljubljana, Slovenia.
#
#  match  found :  ['Juric, Matjaz B.']
# authors_inst_list: ['[Juric, Matjaz B.', ' Univ Ljubljana, Fac Comp & Informat Sci, SI-1000 Ljubljana, Slovenia.'] match ['Juric, Matjaz B.']
#
#  split_name_tokens :  ['Juric, Matjaz B.']
# institution UnivLjubljana
#
#  Comes in try block
# each_author Juric, Matjaz B. ins U
#
#  comes in catch block
# inst_dict {'Juric, Matjaz B.': 'U'}
#
#  c1_str : [Kolozali, Sefki; Barthet, Mathieu; Fazekas, Gyoergy; Sandler, Mark] Queen Mary Univ London, Sch Elect Engn & Comp Sci, London E1 4NS, England.
#
#  match  found :  ['Kolozali, Sefki; Barthet, Mathieu; Fazekas, Gyoergy; Sandler, Mark']
# authors_inst_list: ['[Kolozali, Sefki; Barthet, Mathieu; Fazekas, Gyoergy; Sandler, Mark', ' Queen Mary Univ London, Sch Elect Engn & Comp Sci, London E1 4NS, England.'] match ['Kolozali, Sefki; Barthet, Mathieu; Fazekas, Gyoergy; Sandler, Mark']
#
#  split_name_tokens :  ['Kolozali, Sefki', ' Barthet, Mathieu', ' Fazekas, Gyoergy', ' Sandler, Mark']
# institution QueenMaryUnivLondon
#
#  Comes in try block
# each_author Kolozali, Sefki ins Q
#
#  comes in catch block
# inst_dict {'Kolozali, Sefki': 'Q'}
#
#  c1_str : [Mazandu, Gaston K.; Mulder, Nicola J.] Univ Cape Town, Sch Med, Dept Clin Lab Sci, Inst Infect Dis & Mol Med,Computat Biol Grp, ZA-7925 Cape Town, South Africa.
#
#  match  found :  ['Mazandu, Gaston K.; Mulder, Nicola J.']
# authors_inst_list: ['[Mazandu, Gaston K.; Mulder, Nicola J.', ' Univ Cape Town, Sch Med, Dept Clin Lab Sci, Inst Infect Dis & Mol Med,Computat Biol Grp, ZA-7925 Cape Town, South Africa.'] match ['Mazandu, Gaston K.; Mulder, Nicola J.']
#
#  split_name_tokens :  ['Mazandu, Gaston K.', ' Mulder, Nicola J.']
# institution UnivCapeTown
#
#  Comes in try block
# each_author Mazandu, Gaston K. ins U
#
#  comes in catch block
# inst_dict {'Mazandu, Gaston K.': 'U'}
#
#  c1_str : [Bollegala, Danushka] Univ Tokyo, Dept Informat & Commun Engn, Tokyo, Japan.
#
#  match  found :  ['Bollegala, Danushka']
# authors_inst_list: ['[Bollegala, Danushka', ' Univ Tokyo, Dept Informat & Commun Engn, Tokyo, Japan.'] match ['Bollegala, Danushka']
#
#  split_name_tokens :  ['Bollegala, Danushka']
# institution UnivTokyo
#
#  c1_str : [Shutova, Ekaterina] Univ Calif Berkeley, Inst Cognit & Brain Sci, Berkeley, CA 94720 USA.
#
#  match  found :  ['Shutova, Ekaterina']
# authors_inst_list: ['[Shutova, Ekaterina', ' Univ Calif Berkeley, Inst Cognit & Brain Sci, Berkeley, CA 94720 USA.'] match ['Shutova, Ekaterina']
#
#  split_name_tokens :  ['Shutova, Ekaterina']
# institution UnivCalifBerkeley
#
#  Comes in try block
# each_author Shutova, Ekaterina ins U
#
#  comes in catch block
# inst_dict {'Shutova, Ekaterina': 'U'}
#
#  c1_str : [Thorleuchter, Dirk] Fraunhofer INT, D-53879 Euskirchen, Germany.
#
#  match  found :  ['Thorleuchter, Dirk']
# authors_inst_list: ['[Thorleuchter, Dirk', ' Fraunhofer INT, D-53879 Euskirchen, Germany.'] match ['Thorleuchter, Dirk']
#
#  split_name_tokens :  ['Thorleuchter, Dirk']
# institution FraunhoferINT
#
#  c1_str : [Van den Poel, Dirk] Univ Ghent, Fac Econ & Business Adm, B-9000 Ghent, Belgium.
#
#  match  found :  ['Van den Poel, Dirk']
# authors_inst_list: ['[Van den Poel, Dirk', ' Univ Ghent, Fac Econ & Business Adm, B-9000 Ghent, Belgium.'] match ['Van den Poel, Dirk']
#
# ...
# {'doi': '10.1016/j.clinthera.2013.08.005', 'aulast': ['MARTELL', 'BROOKS', 'WANG', 'WILCOXEN'], 'country': None, 'wosid': 'WOS:000325388600004', 'ayjid': 'MARTELL R 2013 CLINICAL THERAPEUTICS', 'volume': '35', 'citations': [{'doi': None, 'aulast': '[Martell', 'country': None, 'wosid': None, 'ayjid': '[Martell   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}, {'doi': None, 'aulast': '[Martell', 'country': None, 'wosid': None, 'ayjid': '[Martell   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}], 'jtitle': 'CLINICAL THERAPEUTICS', 'address': ['[Martell, Robert E.; Brooks, David G.; Wang, Yan; Wilcoxen, Keith] TESARO Inc, Waltham, MA USA.', '[Martell, Robert E.] Tufts Med Ctr, Boston, MA USA.'], 'atitle': 'Discovery of Novel Drugs for Promising Targets', 'date': 2013, 'epage': '1281', 'pmid': None, 'spage': '1271', 'issue': '9', 'institution': None, 'auinit': ['R', 'D', 'Y', 'K']}
# {'doi': '10.1016/j.compenvurbsys.2013.06.003', 'aulast': ['FARNAGHI', 'MANSOURIAN'], 'country': None, 'wosid': 'WOS:000325122300017', 'ayjid': 'FARNAGHI M 2013 COMPUTERS ENVIRONMENT AND URBAN SYSTEMS', 'volume': '41', 'citations': [{'doi': None, 'aulast': '[Farnaghi', 'country': None, 'wosid': None, 'ayjid': '[Farnaghi   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}, {'doi': None, 'aulast': '[Mansourian', 'country': None, 'wosid': None, 'ayjid': '[Mansourian   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}], 'jtitle': 'COMPUTERS ENVIRONMENT AND URBAN SYSTEMS', 'address': ['[Farnaghi, Mahdi; Mansourian, Ali] KN Toosi Univ Technol, Fac Geodesy & Geomat Engn, Tehran 1996715333, Iran.', '[Mansourian, Ali] Lund Univ, GIS Ctr, Dept Phys Geog & Ecosyst Sci, S-22100 Lund, Sweden.'], 'atitle': 'Disaster planning using automated composition of semantic OGC web services: A case study in sheltering', 'date': 2013, 'epage': '218', 'pmid': None, 'spage': '204', 'issue': None, 'institution': None, 'auinit': ['M', 'A']}
# {'doi': None, 'aulast': ['KHATTAK', 'BATOOL', 'PERVEZ', 'KHAN', 'LEE'], 'country': None, 'wosid': 'WOS:000325302300004', 'ayjid': 'KHATTAK A 2013 JOURNAL OF INFORMATION SCIENCE AND ENGINEERING', 'volume': '29', 'citations': [{'doi': None, 'aulast': '[Khattak', 'country': None, 'wosid': None, 'ayjid': '[Khattak   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}, {'doi': None, 'aulast': '[Khan', 'country': None, 'wosid': None, 'ayjid': '[Khan   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}], 'jtitle': 'JOURNAL OF INFORMATION SCIENCE AND ENGINEERING', 'address': ['[Khattak, Asad Masood; Batool, Rabia; Pervez, Zeeshan; Lee, Sungyoung] Kyung Hee Univ, Dept Comp Engn, Yongin 446701, South Korea.', '[Khan, Adil Mehmood] Ajou Univ, Div Informat & Comp Engn, Gyeonggi Do 443749, South Korea.'], 'atitle': 'Ontology Evolution and Challenges', 'date': 2013, 'epage': '871', 'pmid': None, 'spage': '851', 'issue': '5', 'institution': None, 'auinit': ['A', 'R', 'Z', 'A', 'S']}
# {'doi': None, 'aulast': ['ZHANG', 'MENG'], 'country': None, 'wosid': 'WOS:000324717100001', 'ayjid': 'ZHANG J 2013 CANADIAN JOURNAL OF INFORMATION AND LIBRARY SCIENCE-REVUE CANADIENNE DES SCIENCES DE L INFORMATION ET DE BIBLIOTHECONOMIE', 'volume': '37', 'citations': [{'doi': None, 'aulast': '[Zhang', 'country': None, 'wosid': None, 'ayjid': '[Zhang   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}, {'doi': None, 'aulast': '[Meng', 'country': None, 'wosid': None, 'ayjid': '[Meng   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}], 'jtitle': 'CANADIAN JOURNAL OF INFORMATION AND LIBRARY SCIENCE-REVUE CANADIENNE DES SCIENCES DE L INFORMATION ET DE BIBLIOTHECONOMIE', 'address': ['[Zhang, Jin] Univ Wisconsin Milwaukee, Sch Informat Studies, Milwaukee, WI 53201 USA.', '[Meng, Xi] Renmin Univ China, Sch Informat Resource Management, Beijing, Peoples R China.'], 'atitle': 'Visual Subject Analysis for Dublin Core Research', 'date': 2013, 'epage': '182', 'pmid': None, 'spage': '161', 'issue': '3', 'institution': None, 'auinit': ['J', 'X']}
# {'doi': '10.1016/j.drudis.2013.05.008', 'aulast': ['AZZAOUI', 'JACOBY', 'SENGER', 'RODRIGUEZ', 'LOZA', 'ZDRAZIL', 'PINTO', 'WILLIAMS', 'DE LA TORRE', 'MESTRES', 'PASTOR', 'TABOUREAU', 'RAREY', 'CHICHESTER', 'PETTIFER', 'BLOMBERG', 'HARLAND', 'WILLIAMS-JONES', 'ECKER'], 'country': None, 'wosid': 'WOS:000324719500006', 'ayjid': 'AZZAOUI K 2013 DRUG DISCOVERY TODAY', 'volume': '18', 'citations': [{'doi': None, 'aulast': '[Azzaoui', 'country': None, 'wosid': None, 'ayjid': '[Azzaoui   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}, {'doi': None, 'aulast': '[Senger', 'country': None, 'wosid': None, 'ayjid': '[Senger   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}, {'doi': None, 'aulast': '[Cuadrado', 'country': None, 'wosid': None, 'ayjid': '[Cuadrado Rodriguez  ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 'Rodriguez'}, {'doi': None, 'aulast': '[Zdrazil', 'country': None, 'wosid': None, 'ayjid': '[Zdrazil   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}, {'doi': None, 'aulast': '[Williams', 'country': None, 'wosid': None, 'ayjid': '[Williams   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}, {'doi': None, 'aulast': '[de', 'country': None, 'wosid': None, 'ayjid': '[de la  ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': 'la'}, {'doi': None, 'aulast': '[Mestres', 'country': None, 'wosid': None, 'ayjid': '[Mestres   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}, {'doi': None, 'aulast': '[Mestres', 'country': None, 'wosid': None, 'ayjid': '[Mestres   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}, {'doi': None, 'aulast': '[Taboureau', 'country': None, 'wosid': None, 'ayjid': '[Taboureau   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}, {'doi': None, 'aulast': '[Rarey', 'country': None, 'wosid': None, 'ayjid': '[Rarey   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}, {'doi': None, 'aulast': '[Chichester', 'country': None, 'wosid': None, 'ayjid': '[Chichester   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}, {'doi': None, 'aulast': '[Pettifer', 'country': None, 'wosid': None, 'ayjid': '[Pettifer   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}, {'doi': None, 'aulast': '[Blomberg', 'country': None, 'wosid': None, 'ayjid': '[Blomberg   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}, {'doi': None, 'aulast': '[Harland', 'country': None, 'wosid': None, 'ayji ...
# {'doi': '10.1007/s11390-013-1377-6', 'aulast': ['ZHANG', 'WU', 'SHYU', 'PENG'], 'country': None, 'wosid': 'WOS:000324661300005', 'ayjid': 'ZHANG C 2013 JOURNAL OF COMPUTER SCIENCE AND TECHNOLOGY', 'volume': '28', 'citations': [{'doi': None, 'aulast': '[Zhang', 'country': None, 'wosid': None, 'ayjid': '[Zhang   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}, {'doi': None, 'aulast': '[Shyu', 'country': None, 'wosid': None, 'ayjid': '[Shyu   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}], 'jtitle': 'JOURNAL OF COMPUTER SCIENCE AND TECHNOLOGY', 'address': ['[Zhang, Cheng-De; Wu, Xiao; Peng, Qiang] Southwest Jiaotong Univ, Sch Informat Sci & Technol, Chengdu 610031, Peoples R China.', '[Shyu, Mei-Ling] Univ Miami, Dept Elect & Comp Engn, Coral Gables, FL 33146 USA.'], 'atitle': 'A Novel Web Video Event Mining Framework with the Integration of Correlation and Co-Occurrence Information', 'date': 2013, 'epage': '796', 'pmid': None, 'spage': '788', 'issue': '5', 'institution': None, 'auinit': ['C', 'X', 'M', 'Q']}
# {'doi': '10.1007/s11390-013-1386-5', 'aulast': ['ZHANG', 'ZHAI', 'ZONG'], 'country': None, 'wosid': 'WOS:000324661300014', 'ayjid': 'ZHANG J 2013 JOURNAL OF COMPUTER SCIENCE AND TECHNOLOGY', 'volume': '28', 'citations': [{'doi': None, 'aulast': '[Zhang', 'country': None, 'wosid': None, 'ayjid': '[Zhang   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}], 'jtitle': 'JOURNAL OF COMPUTER SCIENCE AND TECHNOLOGY', 'address': ['[Zhang, Jia-Jun; Zhai, Fei-Fei; Zong, Cheng-Qing] Chinese Acad Sci, Inst Automat, Natl Lab Pattern Recognit, Beijing 100190, Peoples R China.'], 'atitle': 'A Substitution-Translation-Restoration Framework for Handling Unknown Words in Statistical Machine Translation', 'date': 2013, 'epage': '918', 'pmid': None, 'spage': '907', 'issue': '5', 'institution': None, 'auinit': ['J', 'F', 'C']}
# {'doi': '10.1016/j.asoc.2013.05.008', 'aulast': ['BOBILLO', 'STRACCIA'], 'country': None, 'wosid': 'WOS:000324030600005', 'ayjid': 'BOBILLO F 2013 APPLIED SOFT COMPUTING', 'volume': '13', 'citations': [{'doi': None, 'aulast': '[Bobillo', 'country': None, 'wosid': None, 'ayjid': '[Bobillo   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}, {'doi': None, 'aulast': '[Straccia', 'country': None, 'wosid': None, 'ayjid': '[Straccia   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}], 'jtitle': 'APPLIED SOFT COMPUTING', 'address': ['[Bobillo, Fernando] Univ Zaragoza, Dept Comp Sci & Syst Engn, E-50009 Zaragoza, Spain.', '[Straccia, Umberto] CNR, ISTI, I-56100 Pisa, Italy.'], 'atitle': 'Aggregation operators for fuzzy ontologies', 'date': 2013, 'epage': '3830', 'pmid': None, 'spage': '3816', 'issue': '9', 'institution': None, 'auinit': ['F', 'U']}
# {'doi': '10.1007/s00607-012-0239-3', 'aulast': ['KHAN', 'HUSSAIN', 'LATIF', 'AFZAL', 'AHMAD', 'LEE'], 'country': None, 'wosid': 'WOS:000323742500006', 'ayjid': 'KHAN W 2013 COMPUTING', 'volume': '95', 'citations': [{'doi': None, 'aulast': '[Khan', 'country': None, 'wosid': None, 'ayjid': '[Khan   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}, {'doi': None, 'aulast': '[Latif', 'country': None, 'wosid': None, 'ayjid': '[Latif   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}], 'jtitle': 'COMPUTING', 'address': ['[Khan, Wajahat Ali; Hussain, Maqbool; Afzal, Muhammad; Lee, Sungyoung] Kyung Hee Univ, Dept Comp Engn, Yongin 446701, Gyeonggi Do, South Korea.', '[Latif, Khalid; Ahmad, Farooq] Natl Univ Sci & Technol, Sch Elect Engn & Comp Sci, Islamabad 44000, Pakistan.'], 'atitle': 'Process interoperability in healthcare systems with dynamic semantic web services', 'date': 2013, 'epage': '862', 'pmid': None, 'spage': '837', 'issue': '9', 'institution': None, 'auinit': ['W', 'M', 'K', 'M', 'F', 'S']}
# {'doi': '10.1016/j.isprsjprs.2013.02.015', 'aulast': ['YUE', 'DI', 'WEI', 'HAN'], 'country': None, 'wosid': 'WOS:000324013900014', 'ayjid': 'YUE P 2013 ISPRS JOURNAL OF PHOTOGRAMMETRY AND REMOTE SENSING', 'volume': '83', 'citations': [{'doi': None, 'aulast': '[Yue', 'country': None, 'wosid': None, 'ayjid': '[Yue   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}, {'doi': None, 'aulast': '[Yue', 'country': None, 'wosid': None, 'ayjid': '[Yue   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}, {'doi': None, 'aulast': '[Wei', 'country': None, 'wosid': None, 'ayjid': '[Wei   ', 'volume': None, 'citations': None, 'jtitle': None, 'atitle': None, 'date': None, 'epage': None, 'pmid': None, 'spage': None, 'issue': None, 'institution': None, 'auinit': None}], 'jtitle': 'ISPRS JOURNAL OF PHOTOGRAMMETRY AND REMOTE SENSING', 'address': ['[Yue, Peng; Di, Liping; Han, Weiguo] George Mason Univ, CSISS, Fairfax, VA 22032 USA.', '[Yue, Peng] Wuhan Univ, State Key Lab Informat Engn Surveying Mapping & R, Wuhan 430079, Peoples R China.', '[Wei, Yaxing] Oak Ridge Natl Lab, Div Environm Sci, Oak Ridge, TN 37831 USA.'], 'atitle': 'Intelligent services for discovery of complex geospatial features from remote sensing imagery', 'date': 2013, 'epage': '164', 'pmid': None, 'spage': '151', 'issue': None, 'institution': None, 'auinit': ['P', 'L', 'Y', 'W']}

# %%
A =dict()
B =dict()

A= {'A1' : 'I1', 'A2' : 'I1', 'A3' : 'I1','A4' : 'I1'}
B= {'A1' : 'I2', 'A2' : 'I3', 'A5' : 'I2','A8' : 'I5'}
print A,B

for key,val in A.iteritems(),B.iteritems() :
    if A[key] == B[key] :
        print 'yes'
    else :
        print 'no'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-14ad61900e45> in <module>()
#       6 print A,B
#       7
# ----> 8 for key,val in A.iteritems(),B.iteritems() :
#       9     if A[key] == B[key] :
#      10         print 'yes'
#
# ValueError: too many values to unpack
# {'A1': 'I1', 'A3': 'I1', 'A2': 'I1', 'A4': 'I1'} {'A1': 'I2', 'A8': 'I5', 'A2': 'I3', 'A5': 'I2'}

# %%
fruit_available = {'apples': 25, 'oranges': 0, 'mango': 12, 'pineapple': 0 }

my_satchel = {'apples': 1, 'oranges': 0, 'kiwi': 13 }

available = set(fruit_available.keys())
satchel = set(my_satchel.keys())

# fruit not in your satchel, but that is available
print available.difference(satchel)
# Out:
# set(['mango', 'pineapple'])

# %%
import tethne.readers as rd
filepath = "/Users/ramki/tethne/tethne/testsuite/testin/2_testrecords.txt"
wos_list = rd.parse_wos(filepath)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-2-09df222b75eb> in <module>()
#       1 import tethne.readers as rd
#       2 filepath = "/Users/ramki/tethne/tethne/testsuite/testin/2_testrecords.txt"
# ----> 3 wos_list = rd.parse_wos(filepath)
#       4
#       5 if wos_dict['C1'] is not None:
#
# /Users/ramki/tethne/tethne/readers.py in parse_wos(filepath)
#     207                 wos_dict[field_tag] += '\n' + str(line[3:])
#     208             else:
# --> 209                 wos_dict[field_tag] += ' ' + str(line[3:])
#     210         except (KeyError, TypeError):
#     211             #key didn't exist already, can't append but must create
#
# UnboundLocalError: local variable 'wos_dict' referenced before assignment
# comes in readers.parsewos - V6

# %%
 au=['Hristoskova, Anna', ' Volckaert, Bruno', ' De Turck, Filip']
 ins = [ 'ASU']
    
 au_ins= dict()   
 #print au
 #print ins   
    
 for i in au:
     for a in ins:   
        
        try:
            au_ins[i].append(a)
            
        except KeyError,AttributeError:
            au_ins[i] = a
            
 print au_ins
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-d03723892cd5> in <module>()
#      10
#      11        try:
# ---> 12            au_ins[i].append(a)
#      13
#      14        except KeyError,AttributeError:
#
# AttributeError: 'str' object has no attribute 'append'
