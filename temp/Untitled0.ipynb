# %%
a = [212488, 5753, 2563, 1420, 520, 243, 167, 43, 525, 380, 41, 50, 117, 101, 82, 138, 104, 26, 9, 15, 29, 6]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(arange(len(a)), a, 'bo')
plt.yscale('log')
plt.show()

# %%
b = [ a[i]-a[i-1] for i in xrange(2, len(a)) ]

# %%
plt.plot(arange(len(b)), b)
plt.show()
